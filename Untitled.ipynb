# %%
import numpy as pd
import pandas as pd

# %%
exc=pd.read_csv('data/Producto_cafe_chiapas.csv')

# %%
exc.head(50)
# Out:
#     NO. PROG- No. EMPRESA                                      No. de SESIÓN  \
# 0         1.0          54                                           SESIÓN 2
# 1         NaN         NaN                                                NaN
# 2         NaN         NaN                                                NaN
# 3         NaN         NaN                                                NaN
# 4         NaN         NaN                                                NaN
# 5         2.0          55                                           SESIÓN 2
# 6         NaN         NaN                                                NaN
# 7         NaN         NaN                                                NaN
# 8         NaN         NaN                                                NaN
# 9         NaN         NaN                                                NaN
# 10        NaN         NaN                                                NaN
# ...

# %%
exc.shape
# Out:
# (682, 12)
