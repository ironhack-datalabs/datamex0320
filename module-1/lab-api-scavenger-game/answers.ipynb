# %% [markdown]
# Challenge #1

# %%
import json
import requests as req
import pandas as pd

# %%
resp=req.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/forks')
data=pd.DataFrame(resp.json())
data.head()
# Out:
#           id                           node_id         name  \
# 0  252107322  MDEwOlJlcG9zaXRvcnkyNTIxMDczMjI=  datamex0320
# 1  250406096  MDEwOlJlcG9zaXRvcnkyNTA0MDYwOTY=  datamex0320
# 2  249882123  MDEwOlJlcG9zaXRvcnkyNDk4ODIxMjM=  datamex0320
# 3  249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# 4  249830867  MDEwOlJlcG9zaXRvcnkyNDk4MzA4Njc=  datamex0320
#
#                     full_name  private  \
# 0  Polymorphism36/datamex0320    False
# 1     sromero9485/datamex0320    False
# 2      Herguejuan/datamex0320    False
# 3         MayReii/datamex0320    False
# 4     ta-data-mex/datamex0320    False
#
#                                                owner  \
# 0  {'login': 'Polymorphism36', 'id': 31583194, 'n...
# 1  {'login': 'sromero9485', 'id': 61168379, 'node...
# 2  {'login': 'Herguejuan', 'id': 61879880, 'node_...
# 3  {'login': 'MayReii', 'id': 61334507, 'node_id'...
# 4  {'login': 'ta-data-mex', 'id': 51455140, 'node...
#
# ...

# %%
from pandas.io.json import json_normalize

df=json_normalize(resp.json())

df['language']
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0     Jupyter Notebook
# 1                 None
# 2     Jupyter Notebook
# 3                 None
# 4                 None
# 5     Jupyter Notebook
# 6     Jupyter Notebook
# 7     Jupyter Notebook
# 8     Jupyter Notebook
# 9     Jupyter Notebook
# 10                None
# 11    Jupyter Notebook
# 12    Jupyter Notebook
# 13    Jupyter Notebook
# Name: language, dtype: object

# %%
df[df['language'] != 'Jupyter Notebook']
# Out:
#            id                           node_id         name  \
# 1   250406096  MDEwOlJlcG9zaXRvcnkyNTA0MDYwOTY=  datamex0320
# 3   249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# 4   249830867  MDEwOlJlcG9zaXRvcnkyNDk4MzA4Njc=  datamex0320
# 10  249545481  MDEwOlJlcG9zaXRvcnkyNDk1NDU0ODE=  datamex0320
#
#                        full_name  private  \
# 1        sromero9485/datamex0320    False
# 3            MayReii/datamex0320    False
# 4        ta-data-mex/datamex0320    False
# 10  zeferinopanyvino/datamex0320    False
#
#                                            html_url  \
# 1        https://github.com/sromero9485/datamex0320
# 3            https://github.com/MayReii/datamex0320
# 4        https://github.com/ta-data-mex/datamex0320
# 10  https://github.com/zeferinopanyvino/datamex0320
#
#                        description  fork  \
# 1   Data Analytics Bootcamp Mexico  True
# 3   Data Analytics Bootcamp Mexico  True
# 4   Data Analytics Bootcamp Mexico  True
# ...

# %%
df['language'].unique()
# Out:
# array(['Jupyter Notebook', None], dtype=object)

# %% [markdown]
# Challenge #2

# %%
#resp_commits=req.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/commits')
#data_commits=pd.DataFrame(resp_commits.json())
#data_commits.head()

resp2=req.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/commits')
data2=pd.DataFrame(resp2.json())
data2.head()
# Out:
#                                         sha  \
# 0  67c75b67f1a2d0b71a5853841c07d1c275b97da1
# 1  a70431321663197fc35293525e42dde20f493f10
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjQ4NTM5MzEyOjY3Yzc1YjY3ZjFhMmQwYj...
# 1  MDY6Q29tbWl0MjQ4NTM5MzEyOmE3MDQzMTMyMTY2MzE5N2...
#
#                                               commit  \
# 0  {'author': {'name': 'YonatanRA', 'email': 'yeh...
# 1  {'author': {'name': 'YonatanRA', 'email': 'yeh...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/datamex03...
# 1  https://github.com/ironhack-datalabs/datamex03...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
# ...

# %%
#df2=json_normalize(resp_commits.json())
from pandas.io.json import json_normalize

df2=json_normalize(resp2.json())   

df2.filter(["commit.author.date"])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#      commit.author.date
# 0  2020-03-19T15:49:52Z
# 1  2020-03-19T15:36:05Z

# %%
df2["commit.author.date"].count()
# Out:
# 2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 57 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   sha                            2 non-null      object
#  1   node_id                        2 non-null      object
#  2   url                            2 non-null      object
#  3   html_url                       2 non-null      object
#  4   comments_url                   2 non-null      object
#  5   parents                        2 non-null      object
#  6   commit.author.name             2 non-null      object
#  7   commit.author.email            2 non-null      object
#  8   commit.author.date             2 non-null      object
#  9   commit.committer.name          2 non-null      object
#  10  commit.committer.email         2 non-null      object
#  11  commit.committer.date          2 non-null      object
# ...

# %% [markdown]
# Challenge #3

# %%
resp3=req.get('https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/master')
data3=pd.DataFrame(resp3.json())
data3.head()
# Out:
#                                         sha  \
# 0  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 1  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 2  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 3  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 4  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                                 tree  truncated
# 0  {'path': '.gitignore', 'mode': '100644', 'type...      False
# 1  {'path': '15024', 'mode': '040000', 'type': 't...      False
# 2  {'path': '15534', 'mode': '040000', 'type': 't...      False
# 3  {'path': '17020', 'mode': '040000', 'type': 't...      False
# ...

# %%
df3=json_normalize(resp3.json())
df3.head()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                         sha  \
# 0  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                                 tree  truncated
# 0  [{'path': '.gitignore', 'mode': '100644', 'typ...      False
