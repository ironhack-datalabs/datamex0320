# %%
import json
import requests 
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# # 1.- Challenge 1: Fork Languages

# %%
username='rigelalgebar'
token='17b110995b40fd39be09f0124ce14a8f31331933'

fork = requests.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/forks', auth=(username, token))
results_fork = fork.json()

results_fork
# Out:
# [{'id': 252107322,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTIxMDczMjI=',
#   'name': 'datamex0320',
#   'full_name': 'Polymorphism36/datamex0320',
#   'private': False,
#   'owner': {'login': 'Polymorphism36',
#    'id': 31583194,
#    'node_id': 'MDQ6VXNlcjMxNTgzMTk0',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/31583194?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Polymorphism36',
#    'html_url': 'https://github.com/Polymorphism36',
#    'followers_url': 'https://api.github.com/users/Polymorphism36/followers',
#    'following_url': 'https://api.github.com/users/Polymorphism36/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Polymorphism36/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Polymorphism36/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Polymorphism36/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Polymorphism36/orgs',
# ...

# %%
flattned_forks = json_normalize(results_fork)

# %%
language = list(flattned_forks['language'].unique())
language
# Out:
# ['Jupyter Notebook', None]

# %% [markdown]
# # Challenge 2: Count Commits

# %%
commits = requests.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/commits', auth=(username, token))
results_commits = commits.json()

results_commits
# Out:
# [{'sha': '67c75b67f1a2d0b71a5853841c07d1c275b97da1',
#   'node_id': 'MDY6Q29tbWl0MjQ4NTM5MzEyOjY3Yzc1YjY3ZjFhMmQwYjcxYTU4NTM4NDFjMDdkMWMyNzViOTdkYTE=',
#   'commit': {'author': {'name': 'YonatanRA',
#     'email': 'yeho@mail.com',
#     'date': '2020-03-19T15:49:52Z'},
#    'committer': {'name': 'YonatanRA',
#     'email': 'yeho@mail.com',
#     'date': '2020-03-19T15:49:52Z'},
#    'message': 'bootcamp',
#    'tree': {'sha': '1a2c96e336cea722b67af8d3f88420bba76d312d',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/datamex0320/git/trees/1a2c96e336cea722b67af8d3f88420bba76d312d'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamex0320/git/commits/67c75b67f1a2d0b71a5853841c07d1c275b97da1',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/ironhack-datalabs/datamex0320/commits/67c75b67f1a2d0b71a5853841c07d1c275b97da1',
# ...

# %%
flattned_commits = json_normalize(results_commits)

# %%
commits = list(flattned_commits['commit.author.date'])
commits
# Out:
# ['2020-03-19T15:49:52Z', '2020-03-19T15:36:05Z']

# %% [markdown]
# # Challenge 3: Hidden Cold Joke

# %%
scan = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/master', auth=(username,token))
results_scan = scan.json()

results_scan
# Out:
# {'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'tree': [{'path': '.gitignore',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'size': 10,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#   {'path': '15024',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#   {'path': '15534',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '5af6f2a7287e4191f39e55693fc1e9c8918d1d3a',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a'},
#   {'path': '17020',
#    'mode': '040000',
# ...

# %%
json_normalize(results_scan)['tree']
# Out:
# 0    [{'path': '.gitignore', 'mode': '100644', 'typ...
# Name: tree, dtype: object
