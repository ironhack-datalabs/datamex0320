# %%
import json
import requests as req
import pandas as pd

# %%
resp=req.get('https://api.github.com/repos/cateban/datamex0320/commits?since=2020-02-27T00:00:00Z&until=2020-04-06T23:59:59Z')

#since 27 february
#until 4 april

res = resp.json()

res
# Out:
# [{'sha': '4cd20aa6ca037c748802fa1a418e1ba2a4472c25',
#   'node_id': 'MDY6Q29tbWl0MjQ5ODAxMjkxOjRjZDIwYWE2Y2EwMzdjNzQ4ODAyZmExYTQxOGUxYmEyYTQ0NzJjMjU=',
#   'commit': {'author': {'name': 'cateban',
#     'email': 'cardoesteban@gmail.com',
#     'date': '2020-03-26T22:41:02Z'},
#    'committer': {'name': 'cateban',
#     'email': 'cardoesteban@gmail.com',
#     'date': '2020-03-26T22:41:02Z'},
#    'message': '.ds_store',
#    'tree': {'sha': '14ba5cbeabeaedbff13ed6884e6f46e6d3474af5',
#     'url': 'https://api.github.com/repos/cateban/datamex0320/git/trees/14ba5cbeabeaedbff13ed6884e6f46e6d3474af5'},
#    'url': 'https://api.github.com/repos/cateban/datamex0320/git/commits/4cd20aa6ca037c748802fa1a418e1ba2a4472c25',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
#   'url': 'https://api.github.com/repos/cateban/datamex0320/commits/4cd20aa6ca037c748802fa1a418e1ba2a4472c25',
# ...

# %%
commit=[]

for i in range(len(res)):
    commit.append(res[i]['commit'])
    
print('cateban/datamex0320 REPO has',len(commit),'commits')
# Out:
# cateban/datamex0320 REPO has 5 commits

# %%
df = pd.DataFrame(res)

# %%
df
# Out:
#                                         sha  \
# 0  4cd20aa6ca037c748802fa1a418e1ba2a4472c25
# 1  26a8b822421a32db3a0522b2340eb4064cdf92b5
# 2  637eb5a647e01d3bd929bdf1e325342ccdb4f8ac
# 3  67c75b67f1a2d0b71a5853841c07d1c275b97da1
# 4  a70431321663197fc35293525e42dde20f493f10
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjQ5ODAxMjkxOjRjZDIwYWE2Y2EwMzdjNz...
# 1  MDY6Q29tbWl0MjQ5ODAxMjkxOjI2YThiODIyNDIxYTMyZG...
# 2  MDY6Q29tbWl0MjQ5ODAxMjkxOjYzN2ViNWE2NDdlMDFkM2...
# 3  MDY6Q29tbWl0MjQ5ODAxMjkxOjY3Yzc1YjY3ZjFhMmQwYj...
# 4  MDY6Q29tbWl0MjQ5ODAxMjkxOmE3MDQzMTMyMTY2MzE5N2...
#
#                                               commit  \
# 0  {'author': {'name': 'cateban', 'email': 'cardo...
# 1  {'author': {'name': 'cateban', 'email': 'cardo...
# 2  {'author': {'name': 'cateban', 'email': 'cardo...
# 3  {'author': {'name': 'YonatanRA', 'email': 'yeh...
# 4  {'author': {'name': 'YonatanRA', 'email': 'yeh...
#
# ...

# %% [markdown]
# Se pueden ver los 5 commits
