# %%
import json 
import pandas as pd
import requests as req

# %%
resp = req.get("https://api.github.com/repos/MayReii/datamex0320")
resp
# Out:
# <Response [200]>

# %%
df=pd.DataFrame(resp.json())
df
# Out:
#                        id                           node_id         name  \
# login           249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# id              249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# node_id         249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# avatar_url      249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# gravatar_id     249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# ...                   ...                               ...          ...
# license         249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# forks           249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# open_issues     249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# watchers        249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# default_branch  249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
#
#                           full_name  private  \
# login           MayReii/datamex0320    False
# id              MayReii/datamex0320    False
# node_id         MayReii/datamex0320    False
# avatar_url      MayReii/datamex0320    False
# gravatar_id     MayReii/datamex0320    False
# ...                             ...      ...
# license         MayReii/datamex0320    False
# forks           MayReii/datamex0320    False
# open_issues     MayReii/datamex0320    False
# watchers        MayReii/datamex0320    False
# default_branch  MayReii/datamex0320    False
#
#                                                             owner  \
# login                                                     MayReii
# id                                                       61334507
# node_id                                      MDQ6VXNlcjYxMzM0NTA3
# avatar_url      https://avatars3.githubusercontent.com/u/61334...
# gravatar_id
# ...                                                           ...
# license                                                       NaN
# forks                                                         NaN
# open_issues                                                   NaN
# watchers                                                      NaN
# default_branch                                                NaN
#
#                                               html_url  \
# login           https://github.com/MayReii/datamex0320
# id              https://github.com/MayReii/datamex0320
# node_id         https://github.com/MayReii/datamex0320
# avatar_url      https://github.com/MayReii/datamex0320
# gravatar_id     https://github.com/MayReii/datamex0320
# ...                                                ...
# license         https://github.com/MayReii/datamex0320
# forks           https://github.com/MayReii/datamex0320
# open_issues     https://github.com/MayReii/datamex0320
# watchers        https://github.com/MayReii/datamex0320
# default_branch  https://github.com/MayReii/datamex0320
#
#                                    description  fork  \
# login           Data Analytics Bootcamp Mexico  True
# id              Data Analytics Bootcamp Mexico  True
# node_id         Data Analytics Bootcamp Mexico  True
# avatar_url      Data Analytics Bootcamp Mexico  True
# gravatar_id     Data Analytics Bootcamp Mexico  True
# ...                                        ...   ...
# license         Data Analytics Bootcamp Mexico  True
# forks           Data Analytics Bootcamp Mexico  True
# open_issues     Data Analytics Bootcamp Mexico  True
# watchers        Data Analytics Bootcamp Mexico  True
# default_branch  Data Analytics Bootcamp Mexico  True
#
#                                                              url  ...  \
# login           https://api.github.com/repos/MayReii/datamex0320  ...
# id              https://api.github.com/repos/MayReii/datamex0320  ...
# node_id         https://api.github.com/repos/MayReii/datamex0320  ...
# avatar_url      https://api.github.com/repos/MayReii/datamex0320  ...
# gravatar_id     https://api.github.com/repos/MayReii/datamex0320  ...
# ...                                                          ...  ...
# license         https://api.github.com/repos/MayReii/datamex0320  ...
# forks           https://api.github.com/repos/MayReii/datamex0320  ...
# open_issues     https://api.github.com/repos/MayReii/datamex0320  ...
# watchers        https://api.github.com/repos/MayReii/datamex0320  ...
# default_branch  https://api.github.com/repos/MayReii/datamex0320  ...
#
#                          license forks open_issues watchers default_branch  \
# login                        NaN     0           0        0         master
# id                           NaN     0           0        0         master
# node_id         MDc6TGljZW5zZTE=     0           0        0         master
# avatar_url                   NaN     0           0        0         master
# gravatar_id                  NaN     0           0        0         master
# ...                          ...   ...         ...      ...            ...
# license                      NaN     0           0        0         master
# forks                        NaN     0           0        0         master
# open_issues                  NaN     0           0        0         master
# watchers                     NaN     0           0        0         master
# default_branch               NaN     0           0        0         master
#
#                temp_clone_token  \
# login                      None
# id                         None
# node_id                    None
# avatar_url                 None
# gravatar_id                None
# ...                         ...
# license                    None
# forks                      None
# open_issues                None
# watchers                   None
# default_branch             None
#
#                                                            parent  \
# login                                                         NaN
# id                                                      248539312
# node_id                          MDEwOlJlcG9zaXRvcnkyNDg1MzkzMTI=
# avatar_url                                                    NaN
# gravatar_id                                                   NaN
# ...                                                           ...
# license         {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...
# forks                                                          14
# open_issues                                                    35
# watchers                                                        0
# default_branch                                             master
#
#                                                            source  \
# login                                                         NaN
# id                                                      248539312
# node_id                          MDEwOlJlcG9zaXRvcnkyNDg1MzkzMTI=
# avatar_url                                                    NaN
# gravatar_id                                                   NaN
# ...                                                           ...
# license         {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...
# forks                                                          14
# open_issues                                                    35
# watchers                                                        0
# default_branch                                             master
#
#                network_count subscribers_count
# login                     14                 0
# id                        14                 0
# node_id                   14                 0
# avatar_url                14                 0
# gravatar_id               14                 0
# ...                      ...               ...
# license                   14                 0
# forks                     14                 0
# open_issues               14                 0
# watchers                  14                 0
# default_branch            14                 0
#
# [88 rows x 78 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, login to default_branch
# Data columns (total 78 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 88 non-null     int64
#  1   node_id            88 non-null     object
#  2   name               88 non-null     object
#  3   full_name          88 non-null     object
#  4   private            88 non-null     bool
#  5   owner              18 non-null     object
#  6   html_url           88 non-null     object
#  7   description        88 non-null     object
#  8   fork               88 non-null     bool
#  9   url                88 non-null     object
#  10  forks_url          88 non-null     object
#  11  keys_url           88 non-null     object
#  12  collaborators_url  88 non-null     object
#  13  teams_url          88 non-null     object
#  14  hooks_url          88 non-null     object
#  15  issue_events_url   88 non-null     object
#  16  events_url         88 non-null     object
#  17  assignees_url      88 non-null     object
#  18  branches_url       88 non-null     object
#  19  tags_url           88 non-null     object
#  20  blobs_url          88 non-null     object
#  21  git_tags_url       88 non-null     object
#  22  git_refs_url       88 non-null     object
#  23  trees_url          88 non-null     object
#  24  statuses_url       88 non-null     object
#  25  languages_url      88 non-null     object
#  26  stargazers_url     88 non-null     object
#  27  contributors_url   88 non-null     object
#  28  subscribers_url    88 non-null     object
#  29  subscription_url   88 non-null     object
#  30  commits_url        88 non-null     object
#  31  git_commits_url    88 non-null     object
#  32  comments_url       88 non-null     object
#  33  issue_comment_url  88 non-null     object
#  34  contents_url       88 non-null     object
#  35  compare_url        88 non-null     object
#  36  merges_url         88 non-null     object
#  37  archive_url        88 non-null     object
#  38  downloads_url      88 non-null     object
#  39  issues_url         88 non-null     object
#  40  pulls_url          88 non-null     object
#  41  milestones_url     88 non-null     object
#  42  notifications_url  88 non-null     object
#  43  labels_url         88 non-null     object
#  44  releases_url       88 non-null     object
#  45  deployments_url    88 non-null     object
#  46  created_at         88 non-null     object
#  47  updated_at         88 non-null     object
#  48  pushed_at          88 non-null     object
#  49  git_url            88 non-null     object
#  50  ssh_url            88 non-null     object
#  51  clone_url          88 non-null     object
#  52  svn_url            88 non-null     object
#  53  homepage           0 non-null      object
#  54  size               88 non-null     int64
#  55  stargazers_count   88 non-null     int64
#  56  watchers_count     88 non-null     int64
#  57  language           0 non-null      object
#  58  has_issues         88 non-null     bool
#  59  has_projects       88 non-null     bool
#  60  has_downloads      88 non-null     bool
#  61  has_wiki           88 non-null     bool
#  62  has_pages          88 non-null     bool
#  63  forks_count        88 non-null     int64
#  64  mirror_url         0 non-null      object
#  65  archived           88 non-null     bool
#  66  disabled           88 non-null     bool
#  67  open_issues_count  88 non-null     int64
#  68  license            5 non-null      object
#  69  forks              88 non-null     int64
#  70  open_issues        88 non-null     int64
#  71  watchers           88 non-null     int64
#  72  default_branch     88 non-null     object
#  73  temp_clone_token   0 non-null      object
#  74  parent             71 non-null     object
#  75  source             71 non-null     object
#  76  network_count      88 non-null     int64
#  77  subscribers_count  88 non-null     int64
# dtypes: bool(9), int64(11), object(58)
# memory usage: 48.9+ KB

# %%
df.languages_url
# Out:
# login             https://api.github.com/repos/MayReii/datamex03...
# id                https://api.github.com/repos/MayReii/datamex03...
# node_id           https://api.github.com/repos/MayReii/datamex03...
# avatar_url        https://api.github.com/repos/MayReii/datamex03...
# gravatar_id       https://api.github.com/repos/MayReii/datamex03...
#                                         ...
# license           https://api.github.com/repos/MayReii/datamex03...
# forks             https://api.github.com/repos/MayReii/datamex03...
# open_issues       https://api.github.com/repos/MayReii/datamex03...
# watchers          https://api.github.com/repos/MayReii/datamex03...
# default_branch    https://api.github.com/repos/MayReii/datamex03...
# Name: languages_url, Length: 88, dtype: object

# %%
resp = req.get ('https://api.github.com/repos/ironhack-datalabs/datamex0320/forks')
dfork = pd.DataFrame (resp.json())
dfork.head(50)
# Out:
#            id                           node_id         name  \
# 0   252107322  MDEwOlJlcG9zaXRvcnkyNTIxMDczMjI=  datamex0320
# 1   250406096  MDEwOlJlcG9zaXRvcnkyNTA0MDYwOTY=  datamex0320
# 2   249882123  MDEwOlJlcG9zaXRvcnkyNDk4ODIxMjM=  datamex0320
# 3   249835970  MDEwOlJlcG9zaXRvcnkyNDk4MzU5NzA=  datamex0320
# 4   249830867  MDEwOlJlcG9zaXRvcnkyNDk4MzA4Njc=  datamex0320
# 5   249801291  MDEwOlJlcG9zaXRvcnkyNDk4MDEyOTE=  datamex0320
# 6   249771368  MDEwOlJlcG9zaXRvcnkyNDk3NzEzNjg=  datamex0320
# 7   249565118  MDEwOlJlcG9zaXRvcnkyNDk1NjUxMTg=  datamex0320
# 8   249564313  MDEwOlJlcG9zaXRvcnkyNDk1NjQzMTM=  datamex0320
# 9   249550608  MDEwOlJlcG9zaXRvcnkyNDk1NTA2MDg=  datamex0320
# 10  249545481  MDEwOlJlcG9zaXRvcnkyNDk1NDU0ODE=  datamex0320
# 11  249544756  MDEwOlJlcG9zaXRvcnkyNDk1NDQ3NTY=  datamex0320
# 12  249544545  MDEwOlJlcG9zaXRvcnkyNDk1NDQ1NDU=  datamex0320
# 13  248639142  MDEwOlJlcG9zaXRvcnkyNDg2MzkxNDI=  datamex0320
#
#                        full_name  private  \
# 0     Polymorphism36/datamex0320    False
# 1        sromero9485/datamex0320    False
# 2         Herguejuan/datamex0320    False
# 3            MayReii/datamex0320    False
# 4        ta-data-mex/datamex0320    False
# 5            cateban/datamex0320    False
# 6       juan-ivan-NV/datamex0320    False
# 7        Pleomorphic/datamex0320    False
# 8           DavidCis/datamex0320    False
# 9         EsdrasGrau/datamex0320    False
# 10  zeferinopanyvino/datamex0320    False
# 11         cesarcamp/datamex0320    False
# 12      RigelAlgebar/datamex0320    False
# 13        samvhuerta/datamex0320    False
#
#                                                 owner  \
# 0   {'login': 'Polymorphism36', 'id': 31583194, 'n...
# 1   {'login': 'sromero9485', 'id': 61168379, 'node...
# 2   {'login': 'Herguejuan', 'id': 61879880, 'node_...
# 3   {'login': 'MayReii', 'id': 61334507, 'node_id'...
# 4   {'login': 'ta-data-mex', 'id': 51455140, 'node...
# 5   {'login': 'cateban', 'id': 60547004, 'node_id'...
# 6   {'login': 'juan-ivan-NV', 'id': 56144740, 'nod...
# 7   {'login': 'Pleomorphic', 'id': 60831482, 'node...
# 8   {'login': 'DavidCis', 'id': 60921969, 'node_id...
# 9   {'login': 'EsdrasGrau', 'id': 50982522, 'node_...
# 10  {'login': 'zeferinopanyvino', 'id': 61808736, ...
# 11  {'login': 'cesarcamp', 'id': 42099187, 'node_i...
# 12  {'login': 'RigelAlgebar', 'id': 18226397, 'nod...
# 13  {'login': 'samvhuerta', 'id': 62276626, 'node_...
#
#                                            html_url  \
# 0     https://github.com/Polymorphism36/datamex0320
# 1        https://github.com/sromero9485/datamex0320
# 2         https://github.com/Herguejuan/datamex0320
# 3            https://github.com/MayReii/datamex0320
# 4        https://github.com/ta-data-mex/datamex0320
# 5            https://github.com/cateban/datamex0320
# 6       https://github.com/juan-ivan-NV/datamex0320
# 7        https://github.com/Pleomorphic/datamex0320
# 8           https://github.com/DavidCis/datamex0320
# 9         https://github.com/EsdrasGrau/datamex0320
# 10  https://github.com/zeferinopanyvino/datamex0320
# 11         https://github.com/cesarcamp/datamex0320
# 12      https://github.com/RigelAlgebar/datamex0320
# 13        https://github.com/samvhuerta/datamex0320
#
#                        description  fork  \
# 0   Data Analytics Bootcamp Mexico  True
# 1   Data Analytics Bootcamp Mexico  True
# 2   Data Analytics Bootcamp Mexico  True
# 3   Data Analytics Bootcamp Mexico  True
# 4   Data Analytics Bootcamp Mexico  True
# 5   Data Analytics Bootcamp Mexico  True
# 6   Data Analytics Bootcamp Mexico  True
# 7   Data Analytics Bootcamp Mexico  True
# 8   Data Analytics Bootcamp Mexico  True
# 9   Data Analytics Bootcamp Mexico  True
# 10  Data Analytics Bootcamp Mexico  True
# 11  Data Analytics Bootcamp Mexico  True
# 12  Data Analytics Bootcamp Mexico  True
# 13  Data Analytics Bootcamp Mexico  True
#
#                                                   url  ... forks_count  \
# 0   https://api.github.com/repos/Polymorphism36/da...  ...           0
# 1   https://api.github.com/repos/sromero9485/datam...  ...           0
# 2   https://api.github.com/repos/Herguejuan/datame...  ...           0
# 3    https://api.github.com/repos/MayReii/datamex0320  ...           0
# 4   https://api.github.com/repos/ta-data-mex/datam...  ...           0
# 5    https://api.github.com/repos/cateban/datamex0320  ...           0
# 6   https://api.github.com/repos/juan-ivan-NV/data...  ...           0
# 7   https://api.github.com/repos/Pleomorphic/datam...  ...           0
# 8   https://api.github.com/repos/DavidCis/datamex0320  ...           0
# 9   https://api.github.com/repos/EsdrasGrau/datame...  ...           0
# 10  https://api.github.com/repos/zeferinopanyvino/...  ...           0
# 11  https://api.github.com/repos/cesarcamp/datamex...  ...           0
# 12  https://api.github.com/repos/RigelAlgebar/data...  ...           0
# 13  https://api.github.com/repos/samvhuerta/datame...  ...           0
#
#    mirror_url archived disabled open_issues_count  \
# 0        None    False    False                 0
# 1        None    False    False                 0
# 2        None    False    False                 0
# 3        None    False    False                 0
# 4        None    False    False                 0
# 5        None    False    False                 0
# 6        None    False    False                 0
# 7        None    False    False                 0
# 8        None    False    False                 0
# 9        None    False    False                 0
# 10       None    False    False                 0
# 11       None    False    False                 0
# 12       None    False    False                 0
# 13       None    False    False                 0
#
#                                               license forks open_issues  \
# 0   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 1   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 2   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 3   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 4   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 5   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 6   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 7   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 8   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 9   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 10  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 11  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 12  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
# 13  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...     0           0
#
#    watchers default_branch
# 0         0         master
# 1         0         master
# 2         0         master
# 3         0         master
# 4         0         master
# 5         0         master
# 6         0         master
# 7         0         master
# 8         0         master
# 9         0         master
# 10        0         master
# 11        0         master
# 12        0         master
# 13        0         master
#
# [14 rows x 73 columns]
