# %%
import json
import requests as req

# %%
username = 'DavidCis'
token = '7ecd6c1db244b150047d2aeb765cff3176f26647'

fork = req.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/forks', auth=(username,token))
results_fork=fork.json()
results_fork
# Out:
# {'documentation_url': 'https://developer.github.com/v3',
#  'message': 'Bad credentials'}

# %%
import pandas as pd

data = pd.DataFrame(results_fork)
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a0993ed2cc0f> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.DataFrame(results_fork)
#       4 data.head()
#
# /home/david/.local/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# /home/david/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# ...

# %%
from pandas.io.json import json_normalize


flattened_data_fork = json_normalize(results_fork)

flattened_data_fork.head()

# %%
flattened_data_fork["language"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b6828fd97e3b> in <module>()
# ----> 1 flattened_data_fork["language"]
#
# NameError: name 'flattened_data_fork' is not defined

# %%
commit = req.get('https://api.github.com/repos/ironhack-datalabs/datamex0320/commits', auth=(username,token))
results_commit=commit.json()
results_commit
# Out:
# [{'author': {'avatar_url': 'https://avatars3.githubusercontent.com/u/47545401?v=4',
#    'events_url': 'https://api.github.com/users/YonatanRA/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/YonatanRA/followers',
#    'following_url': 'https://api.github.com/users/YonatanRA/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/YonatanRA/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/YonatanRA',
#    'id': 47545401,
#    'login': 'YonatanRA',
#    'node_id': 'MDQ6VXNlcjQ3NTQ1NDAx',
#    'organizations_url': 'https://api.github.com/users/YonatanRA/orgs',
#    'received_events_url': 'https://api.github.com/users/YonatanRA/received_events',
#    'repos_url': 'https://api.github.com/users/YonatanRA/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/YonatanRA/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/YonatanRA/subscriptions',
# ...

# %%
flattened_data_commit = json_normalize(results_commit)

flattened_data_commit.head()#Solo hay 2 commits en este repo
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                         sha  \
# 0  67c75b67f1a2d0b71a5853841c07d1c275b97da1
# 1  a70431321663197fc35293525e42dde20f493f10
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjQ4NTM5MzEyOjY3Yzc1YjY3ZjFhMmQwYj...
# 1  MDY6Q29tbWl0MjQ4NTM5MzEyOmE3MDQzMTMyMTY2MzE5N2...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/datamex03...
# 1  https://github.com/ironhack-datalabs/datamex03...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# ...

# %%
scavenger = req.get('https://api.github.com/repos/ironhack-datalabs/scavenger/content/', auth=(username,token))
results_scavenger=scavenger.json()
results_scavenger
# Out:
# {'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'tree': [{'mode': '100644',
#    'path': '.gitignore',
#    'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'size': 10,
#    'type': 'blob',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#   {'mode': '040000',
#    'path': '15024',
#    'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#    'type': 'tree',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#   {'mode': '040000',
#    'path': '15534',
#    'sha': '5af6f2a7287e4191f39e55693fc1e9c8918d1d3a',
#    'type': 'tree',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/5af6f2a7287e4191f39e55693fc1e9c8918d1d3a'},
#   {'mode': '040000',
#    'path': '17020',
#    'sha': '9c49f920aa4d9433fa99a5824128f0e6b90ec5f2',
#    'type': 'tree',
# ...

# %%
flattened_data_scavenger = json_normalize(results_scavenger)

flattened_data_scavenger.head()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                         sha  \
# 0  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                                 tree  truncated
# 0  [{'path': '.gitignore', 'mode': '100644', 'typ...      False

# %%
flattened_data_scavenger = json_normalize(results_scavenger["tree"])
flattened_data_scavenger.head()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#          path    mode  type                                       sha  size  \
# 0  .gitignore  100644  blob  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf  10.0
# 1       15024  040000  tree  2945e51c87ad5da893c954afcf092f06343bbb7d   NaN
# 2       15534  040000  tree  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a   NaN
# 3       17020  040000  tree  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2   NaN
# 4       30351  040000  tree  c488d7f64088c852e22067d48fdc64ee3670f3ba   NaN
#
#                                                  url
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# ...

# %%
flattened_data_scavenger.url
# Out:
# 0     https://api.github.com/repos/ironhack-datalabs...
# 1     https://api.github.com/repos/ironhack-datalabs...
# 2     https://api.github.com/repos/ironhack-datalabs...
# 3     https://api.github.com/repos/ironhack-datalabs...
# 4     https://api.github.com/repos/ironhack-datalabs...
# 5     https://api.github.com/repos/ironhack-datalabs...
# 6     https://api.github.com/repos/ironhack-datalabs...
# 7     https://api.github.com/repos/ironhack-datalabs...
# 8     https://api.github.com/repos/ironhack-datalabs...
# 9     https://api.github.com/repos/ironhack-datalabs...
# 10    https://api.github.com/repos/ironhack-datalabs...
# 11    https://api.github.com/repos/ironhack-datalabs...
# 12    https://api.github.com/repos/ironhack-datalabs...
# 13    https://api.github.com/repos/ironhack-datalabs...
# 14    https://api.github.com/repos/ironhack-datalabs...
# 15    https://api.github.com/repos/ironhack-datalabs...
# 16    https://api.github.com/repos/ironhack-datalabs...
# ...
