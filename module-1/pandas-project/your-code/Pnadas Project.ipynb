# %%
import pandas as pd
import numpy as np
import warnings 
warnings.simplefilter("ignore")

# %%
#importando bases de datos y convirtiendo a dataframe

sharkdf=pd.read_csv('attacks.csv', sep=',', encoding='latin-1')

sharkdf.shape
# Out:
# (25723, 24)

# %%
#Inspeccionando base de datos
sharkdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
sharkdf
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharkdf.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharkdf = sharkdf.rename(columns={'Species ': 'Species', 'Sex ': 'Sex', 'Fatal (Y/N)' : 'Fatal',
                                  'Investigator or Source': 'InvestigatorSource', 'href formula': 'hrefformula',
                                  'Case Number.1': 'CaseNumber.1', 'Case Number.2': 'CaseNumber.2', 
                                 'original order': 'originalorder', 'Unnamed: 22': 'Unnamed22', 'Unnamed: 23': 'Unnamed23', 'Case Number': 'CaseNumber'})
sharkdf.columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
#        'InvestigatorSource', 'pdf', 'hrefformula', 'href', 'CaseNumber.1',
#        'CaseNumber.2', 'originalorder', 'Unnamed22', 'Unnamed23'],
#       dtype='object')

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber            17021
# Date                  19421
# Year                  19423
# Type                  19425
# Country               19471
# Area                  19876
# Location              19961
# Activity              19965
# Name                  19631
# Sex                   19986
# Age                   22252
# Injury                19449
# Fatal                 19960
# Time                  22775
# Species               22259
# InvestigatorSource    19438
# pdf                   19421
# hrefformula           19422
# href                  19421
# CaseNumber.1          19421
# CaseNumber.2          19421
# originalorder         19414
# Unnamed22             25722
# Unnamed23             25721
# dtype: int64

# %%
sharkdf.T.shape
# Out:
# (24, 25723)

# %%
#Cuando transponemos la tabla, si la columna tiene más de la mitad de NaN no lo consideraremos.
MaxNa = 15
sharkdf=sharkdf.T.loc[:, (sharkdf.T.isnull().sum(axis=0) <= MaxNa)]

# %%
sharkdf=sharkdf.T

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber               1
# Date                     0
# Year                     2
# Type                     4
# Country                 50
# Area                   455
# Location               540
# Activity               544
# Name                   210
# Sex                    565
# Age                   2831
# Injury                  28
# Fatal                  539
# Time                  3354
# Species               2838
# InvestigatorSource      17
# pdf                      0
# hrefformula              1
# href                     0
# CaseNumber.1             0
# CaseNumber.2             0
# originalorder            0
# Unnamed22             6301
# Unnamed23             6300
# dtype: int64

# %%
sharkdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CaseNumber          6301 non-null   object
#  1   Date                6302 non-null   object
#  2   Year                6300 non-null   object
#  3   Type                6298 non-null   object
#  4   Country             6252 non-null   object
#  5   Area                5847 non-null   object
#  6   Location            5762 non-null   object
#  7   Activity            5758 non-null   object
#  8   Name                6092 non-null   object
#  9   Sex                 5737 non-null   object
#  10  Age                 3471 non-null   object
#  11  Injury              6274 non-null   object
#  12  Fatal               5763 non-null   object
#  13  Time                2948 non-null   object
#  14  Species             3464 non-null   object
# ...

# %%
#Comenzamos limpiando los años
#Solo consideramos de 1900 a 2018

sharkdf.Year.unique()
# Out:
# array([2018.0, 2017.0, nan, 2016.0, 2015.0, 2014.0, 2013.0, 2012.0,
#        2011.0, 2010.0, 2009.0, 2008.0, 2007.0, 2006.0, 2005.0, 2004.0,
#        2003.0, 2002.0, 2001.0, 2000.0, 1999.0, 1998.0, 1997.0, 1996.0,
#        1995.0, 1984.0, 1994.0, 1993.0, 1992.0, 1991.0, 1990.0, 1989.0,
#        1969.0, 1988.0, 1987.0, 1986.0, 1985.0, 1983.0, 1982.0, 1981.0,
#        1980.0, 1979.0, 1978.0, 1977.0, 1976.0, 1975.0, 1974.0, 1973.0,
#        1972.0, 1971.0, 1970.0, 1968.0, 1967.0, 1966.0, 1965.0, 1964.0,
#        1963.0, 1962.0, 1961.0, 1960.0, 1959.0, 1958.0, 1957.0, 1956.0,
#        1955.0, 1954.0, 1953.0, 1952.0, 1951.0, 1950.0, 1949.0, 1948.0,
#        1848.0, 1947.0, 1946.0, 1945.0, 1944.0, 1943.0, 1942.0, 1941.0,
#        1940.0, 1939.0, 1938.0, 1937.0, 1936.0, 1935.0, 1934.0, 1933.0,
#        1932.0, 1931.0, 1930.0, 1929.0, 1928.0, 1927.0, 1926.0, 1925.0,
#        1924.0, 1923.0, 1922.0, 1921.0, 1920.0, 1919.0, 1918.0, 1917.0,
# ...

# %%
sharkdf.Year.isnull().sum()
# Out:
# 2

# %%
sharkdf.Year = sharkdf.Year.astype(float)

# %%
sharkdf = sharkdf[sharkdf['Year'] >= 1900]

# %%
sharkdf.Year=sharkdf.Year.dropna()

# %%
sharkdf.Year.isnull().sum()
# Out:
# 0

# %%
sharkdf.Year.unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#        1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986., 1985.,
#        1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975.,
#        1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1947.,
#        1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939., 1938.,
#        1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930., 1929.,
#        1928., 1927., 1926., 1925., 1924., 1923., 1922., 1921., 1920.,
#        1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912., 1911.,
#        1910., 1909., 1908., 1907., 1906., 1905., 1904., 1903., 1902.,
#        1901., 1900.])

# %%
sharkdf.shape
# Out:
# (5562, 24)

# %%
sharkdf.dropna(subset=['Type'], inplace=True)
sharkdf.dropna(subset=['CaseNumber'], inplace=True)
sharkdf.dropna(subset=['hrefformula'], inplace=True)

# %%
sharkdf.dropna(subset=['Species'], inplace=True)
sharkdf.dropna(subset=['Location'], inplace=True)

# %%
sharkdf.shape
# Out:
# (3138, 24)

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber               0
# Date                     0
# Year                     0
# Type                     0
# Country                  3
# Area                    79
# Location                 0
# Activity               172
# Name                    75
# Sex                    275
# Age                   1018
# Injury                   7
# Fatal                  409
# Time                  1286
# Species                  0
# InvestigatorSource       7
# pdf                      0
# hrefformula              0
# href                     0
# CaseNumber.1             0
# CaseNumber.2             0
# originalorder            0
# Unnamed22             3138
# Unnamed23             3138
# dtype: int64

# %%
#Limpiando el tiempo
sharkdf.Time.head(50)
# Out:
# 0              18h00
# 3                NaN
# 4                NaN
# 6     Late afternoon
# 7                NaN
# 8              17h00
# 10           Morning
# 13             08h15
# 14               NaN
# 16             10h30
# 18             10h40
# 20             07h00
# 21             09h30
# 22         Afternoon
# 23             21h50
# 24             09h40
# 25               NaN
# 26               NaN
# 30             09h30
# 31               NaN
# 32             17h00
# 33             18h00
# 34             15h00
# 35             09h30
# 36             17h35
# 37             15h30
# 38             07h30
# 39               NaN
# 40       19h00, Dusk
# 42             16h00
# 43             18h00
# 44               NaN
# 45               NaN
# 46               NaN
# 47             08h00
# 48             15h30
# 49             15h01
# 50               NaN
# 51    Late afternoon
# 52               NaN
# 53             18h00
# 55               NaN
# 57               NaN
# ...

# %%
#Importamos regex y filtramos
import re
sharkdf.Time=sharkdf.Time.astype(str).apply(lambda x : re.sub('[a-zA-Z]','', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('-\d\d\d\d','', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('\d\d\d\d/\d\d\d\d','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('\d\d\d\d / \d\d\d\d','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('>\d\d\d\d','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('\d\d\d\d & \d\d\d\d','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('\xa0 ','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('"  1100"','1100', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('  1200','1200', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('0900 - 0930','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('    2000.08.21','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('1400 - 1500','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('8:04','2000', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('180','1800', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('2045()','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('170','1700', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('103001330','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('100001400','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('150001545','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('1000  1400','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('1030  1330','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('0 ()','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('-','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('2   ','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub(' 05000800','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('17001740','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('16301800','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('1830?','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('00','0', x))
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub(' 140','1400', x))

# %%
sharkdf.Time = pd.to_numeric(sharkdf['Time'], errors='coerce')

# %%
sharkdf = sharkdf[sharkdf['Time'] >= 0]

# %%
sharkdf.Time.unique()
# Out:
# array([1.8000e+03, 1.7000e+03, 8.1500e+02, 1.0300e+03, 1.0400e+03,
#        7.0000e+01, 9.3000e+02, 2.1500e+03, 9.4000e+02, 1.5000e+02,
#        1.7350e+03, 1.5300e+03, 7.3000e+02, 1.6000e+02, 8.0000e+01,
#        1.5010e+03, 1.3450e+03, 2.3300e+03, 9.0000e+01, 1.4300e+03,
#        0.0000e+00, 1.2300e+03, 1.4000e+02, 1.8450e+03, 6.0000e+01,
#        1.0000e+02, 1.3300e+03, 1.0450e+03, 1.1200e+03, 7.4500e+02,
#        1.1000e+02, 1.9300e+03, 8.3000e+02, 1.5450e+03, 1.2000e+02,
#        8.5000e+02, 2.0000e+01, 1.5150e+03, 1.6300e+03, 1.1300e+03,
#        2.2000e+02, 1.6200e+03, 1.5250e+03, 1.7300e+03, 1.3200e+03,
#        1.0150e+03, 1.8150e+03, 1.3500e+03, 1.9200e+03, 1.0250e+03,
#        1.6450e+03, 1.5520e+03, 6.1500e+02, 1.4400e+03, 1.9450e+03,
#        1.9000e+02, 1.0100e+03, 8.4500e+02, 1.2100e+03, 1.8050e+03,
#        1.2250e+03, 1.7510e+03, 1.6120e+03, 1.2450e+03, 1.0500e+03,
#        1.4150e+03, 1.3000e+02, 9.4500e+02, 1.1450e+03, 6.4500e+02,
# ...

# %%
sharkdf['Age']=sharkdf['Age'].fillna('Unknown')

# %%
sharkdf.Age.unique()
# Out:
# array(['57', '15', '21', 'Unknown', '30', '60', '32', '33', '12', '19',
#        '25', '10', '69', '18', '35', '40s', '54', '22', '31', '40', '37',
#        '13', '34', '50', '46', '48', '17', '28', '55', '20', '65', '73',
#        '58', '36', '60s', '51', '61', '59', '42', '6', '27', '29', '23',
#        '24', '43', '9', '44', '14', '62', '52', '38', '68', '16', '11',
#        '47', '63', '26', '71', '41', '53', '20s', '39', '66', '45', '74',
#        '64', '8', '56', '49', '7', '70', '18 or 20', '30s', '77',
#        '36 & 26', '8 or 10', ' ', '30 or 36', '6½', '5', ' 28', '20?',
#        '67', '>50', '9 & 12', '21, 34,24 & 35', '13 or 18', '7 or 8'],
#       dtype=object)

# %%
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('[a-zA-Z]','', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('>\d\d','', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('\d  \d','', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('""','', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('\d\d & \d\d', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('\d & \d\d', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub( "60'", '60', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('-20', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('\xa0', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('20?', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub(' 30', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub(' 8', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('0', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub(' 43', '43', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub(' 11', '11', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('. 33', '33', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('1, 34,', '33', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('37, 67, 35, 7,  ? & 7', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('6½', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('1 & ', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub(' & 19', '', x)) 
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub(' & 7', '', x)) 
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('37, 67, 35, 7, ', '', x))
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('40s', '', x)) 
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('60s', '', x))

# %%
sharkdf.shape
# Out:
# (1560, 24)

# %%
list(sharkdf.Age.unique())
# Out:
# ['57',
#  '15',
#  '1',
#  '',
#  '3',
#  '6',
#  '33',
#  '19',
#  '5',
#  '69',
#  '18',
#  '35',
#  '4',
#  '54',
#  '31',
#  '37',
#  '13',
#  '34',
#  '46',
#  '48',
#  '17',
#  '8',
#  '55',
#  '65',
#  '73',
#  '58',
#  '36',
#  '51',
#  '61',
#  '59',
#  '7',
#  '9',
#  '43',
#  '44',
#  '14',
#  '38',
#  '68',
#  '16',
#  '11',
#  '47',
#  '63',
#  '71',
#  '41',
#  '53',
#  '39',
#  '66',
#  '45',
#  '74',
#  '64',
#  '56',
#  '49',
#  '77',
#  ' ',
#  '?',
#  '67']

# %%
sharkdf.Age = pd.to_numeric(sharkdf['Age'], errors='coerce')

# %%
list(sharkdf.Age.unique())
# Out:
# [57.0,
#  15.0,
#  1.0,
#  nan,
#  3.0,
#  6.0,
#  33.0,
#  19.0,
#  5.0,
#  69.0,
#  18.0,
#  35.0,
#  4.0,
#  54.0,
#  31.0,
#  37.0,
#  13.0,
#  34.0,
#  46.0,
#  48.0,
#  17.0,
#  8.0,
#  55.0,
#  65.0,
#  73.0,
#  58.0,
#  36.0,
#  51.0,
#  61.0,
#  59.0,
#  7.0,
#  9.0,
#  43.0,
#  44.0,
#  14.0,
#  38.0,
#  68.0,
#  16.0,
#  11.0,
#  47.0,
#  63.0,
#  71.0,
#  41.0,
#  53.0,
#  39.0,
#  66.0,
#  45.0,
#  74.0,
#  64.0,
#  56.0,
#  49.0,
#  77.0,
#  67.0]

# %%
sharkdf.Age.isnull().sum()
# Out:
# 342

# %%
sharkdf = sharkdf[sharkdf['Age'] >= 0]

# %%
sharkdf.Age.unique()
# Out:
# array([57., 15.,  1.,  3.,  6., 33., 19.,  5., 69., 18., 35.,  4., 54.,
#        31., 37., 13., 34., 46., 48., 17.,  8., 55., 65., 73., 58., 36.,
#        51., 61., 59.,  7.,  9., 43., 44., 14., 38., 68., 16., 11., 47.,
#        63., 71., 41., 53., 39., 66., 45., 74., 64., 56., 49., 77., 67.])

# %%
sharkdf.shape
# Out:
# (1218, 24)

# %%
sharkdf.Age.isnull().sum()
# Out:
# 0

# %%
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\w\w\w\w\w\w\w\w ','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('-\d\d\d\d','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\w\w\w\w\w\w ','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\w\w\w \d\d\d\d','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\d\d\d\d','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 12-Sep','12-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 07-Sep','07-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('3-Jul','03-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 01-Sep','01-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 14-Aug','14-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 13-Sep','13-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 05-Aug','05-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('  29-Jul','29-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 27-Mar','27-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('    10-Jan','10-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('003-Jul','03-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('103-Jul','13-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 14-Sep','14-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('19-Jul.b','19-Jul',x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('190Feb','19-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Summer','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     13-Apr','13-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     23-Apr','23-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     27-Sep','27-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Aug','01-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 19-Jul to have  "on the weekend"','9-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 24-Jan','24-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Early Sep','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Early Jun','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     03-Mar','03-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('13 -Nov','13-Nov', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Early Aug','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     23-Aug','23-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 13-Jan','13-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('to have taken place in ','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     05-Jan','05-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('5-Jul','05-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('101-Aug','11-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('  29-Oct','29-Oct', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('19-Jul.a','19-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('0001-Aug','01-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     19-Feb','19-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Mid Jul or mid Jul','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('04-','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('     10-Nov','10-Nov', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('05 ','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('13 or 30-May','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\n.12.15.R','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('11-Sep to 16-Sep','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('  21-Jun','21-Jun', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Some time b08-Jan & 21-Jan','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('5-Apr','05-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('4','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 28-Mar','28-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Jul- to Sep','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-May','02-May', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('205-Apr','25-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Apr','02-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('005-Apr','05-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Late Aug','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('5-Mar','05-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('  05-Oct','05-Oct', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('Early Feb','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Apr','01-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Mar','01-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Feb','02-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('9-Mar','09-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Apr','02-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Feb','01-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Jan','01-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Nov','02-Nov', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Nov','01-Nov', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Jul','01-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Sep','02-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Dec','02-Dec', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('   06-Aug','06-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2002-Apr','', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('002-Apr','02-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('105-Apr','15-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('301-Mar','31-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('001-Feb','01-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('201-Jan','21-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('002-Sep','02-Sep', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('001-Aug','01-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('203-Jul','23-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Jul','01-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Jun','01-Jun', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('101-Feb','11-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('101-Mar','11-Mar', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('105-Jul','15-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('002-Feb','02-Feb', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('2-Jan','02-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('101-Jan','11-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('102-Jan','12-Jan', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('001-JUl','01-JUl', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1001-Jul','11-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('101-Jun','11-Jun', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('102-Apr','12-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('002-Apr','02-Apr', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('002-Jan','02-Jan', x))

sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub(' 001-Jul','001-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('201-Jun','21-Jun', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('001-Nov','01-Nov', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('3001-Jul','31-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('205-Jul','25-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('0001-Jul','01-Jul', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('001-Jun','01-Jun', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('1-Oct','01-Oct', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('301-Augun','31-Aug', x))
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('201-Mar','21-Mar', x))

# %%
sharkdf.Date.unique()
# Out:
# array(['25-Jun', '26-May', '13-May', '28-Apr', '25-Apr', '23-Apr', '',
#        '05-Apr', '03-Apr', '31-Mar', '01-Mar', '09-Mar', '15-Feb',
#        '28-Jan', '21-Jan', '31-Dec', '02-Nov', '13-Nov', '28-Oct',
#        '09-Oct', '05-Oct', '02-Sep', '13-Sep', '10-Sep', '29-Aug',
#        '23-Aug', '10-Aug', '03-Aug', '29-Jul', '22-Jul', '20-Jul',
#        '09-Jul', '07-Jul', '18-Jun', '11-Jun', '02-Jun', '03-May',
#        '17-Apr', '01-Apr', '02-Apr', '09-Jan', '19-Dec', '01-Dec',
#        '28-Nov', '01-Nov', '201-Oct', '26-Sep', '11-Sep', '07-Sep',
#        '06-Aug', '15-Jul', 'Jul', '27-Jun', '21-Jun', '01-Jun', '07-Jun',
#        '05-Jun', '31-May', '29-May', '15-May', '19-Apr', '09-Apr',
#        '02-Jan', '21-Dec', '20-Nov', '07-Nov', '25-Oct', '19-Oct',
#        '17-Oct', 'Oct', '20-Sep', '08-Sep', '06-Sep', '05-Sep', 'Sep',
#        '01-Sep', '20-Aug', '19-Aug', '18-Aug', '31-Jul', '26-Jul',
#        '25-Jul', '10-Jul', '03-Jul', '02-Jul', '01-Jul', '30-Jun',
# ...

# %%
list(sharkdf.Species.unique())
# Out:
# ['White shark',
#  "Bull shark, 6'",
#  'Invalid incident',
#  'Tiger shark',
#  '3 m shark',
#  'White shark, 2.5 m',
#  'Bull shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Bull shark, 2 m',
#  'Bull shark, 3 m ',
#  'White shark, 4.6 m',
#  '2 m shark',
#  'Wobbegong shark, 1 m',
#  'Tiger shark, 8 to 10 feet',
#  "8' shark",
#  'Questionable',
#  "5' to 6' shark",
#  'White shark, 3 to 3.5m ',
#  'White shark, 3 m',
#  "White shark, 5' to 7'",
#  'Possibly a juvenile blacktip shark',
#  "4' shark",
#  'A small shark',
#  '"A small shark"',
#  "White shark, 11' to 13'",
#  "White shark, 8' to 10'",
#  "Bull shark, 4' to 5'",
#  'Bull shark, 2m',
#  'White shark, 4 m',
#  'Shark involvement highly doubtful',
#  "Bull shark, 5' to 7'",
#  'Bull shark, 4 m',
#  'Bull shark, 1 m',
#  'Broadnose sevengill shark, 1.5 m',
#  " 6' to 8' shark",
#  'White shark, 3.5 m',
#  "3' to 4' shark",
#  "Tiger shark, 10'",
#  "Tiger shark, 10' ",
# ...

# %%
sharkdf['Species']=sharkdf['Species'].fillna('Unknown')

# %%
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[0-9]','', x)) #quito los números
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[\W]','', x))  
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?white[a-z ]* ?\W?','White', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?blue[a-z ]* ?\W?','Blue', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?lemon[a-z ]* ?\W?','Lemon', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?bull[a-z ]* ?\W?','Bull', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?mako[a-z ]* ?\W?','Mako', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?blacktip[a-z ]* ?\W?','Blacktip', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?nurse[a-z ]* ?\W?','Nurse', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?goblin[a-z ]* ?\W?','Goblin', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?spinner[a-z ]* ?\W?','Spinner', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?dusky[a-z ]* ?\W?','Dusky', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?galapagos[a-z ]* ?\W?','Galapagos', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?leopard[a-z ]* ?\W?','Leopard', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?bronze[a-z ]* ?\W?','Bronze', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?raggedtooth[a-z ]* ?\W?','Raggedtooth', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?grey[a-z ]* ?\W?','Grey', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?hammerhead[a-z ]* ?\W?','Hammerhead', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?angel[a-z ]* ?\W?','Angel', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?reef[a-z ]* ?\W?','Reef', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?dogfish[a-z ]* ?\W?','Dogfish', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?carpet[a-z ]* ?\W?','Carpet', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?banjo[a-z ]* ?\W?','Banjo', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?cleucas[a-z ]* ?\W?','Cleucas', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?spurdog[a-z ]* ?\W?','Spurdog', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?bull[a-z ]* ?\W?','Bull', x))
sharkdf['Species1']=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiger[a-z ]* ?\W?','Tiger', x))

# %%
sharkdf.Species1.unique()
# Out:
# array(['White shark', "Bull shark, 6'", 'Invalid incident', 'Tiger shark',
#        '3 m shark', 'White shark, 2.5 m', 'Bull shark',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Bull shark, 2 m', 'Bull shark, 3 m ',
#        'White shark, 4.6 m', '2 m shark', 'Wobbegong shark, 1 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        "White shark, 5' to 7'", 'Possibly a juvenile blacktip shark',
#        "4' shark", 'A small shark', '"A small shark"',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'Bull shark, 2m', 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Broadnose sevengill shark, 1.5 m', " 6' to 8' shark",
#        'White shark, 3.5 m', "3' to 4' shark", "Tiger shark, 10'",
# ...

# %% [markdown]
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))
# sharkdf.Species=sharkdf.Species.apply(lambda x : re.sub('[a-z ]*?[san]?[d]tiguer[a-z ]* ?\W?','Unknown', x))

# %%
sharkdf.Sex = sharkdf.Sex.fillna('Unknown')

# %%
sharkdf.Sex
# Out:
# 0       F
# 8       M
# 13      M
# 18      M
# 21      M
#        ..
# 5273    M
# 5311    M
# 5375    M
# 5484    M
# 5545    M
# Name: Sex, Length: 1218, dtype: object

# %%
sharkdf.Sex.unique()
# Out:
# array(['F', 'M', 'lli', 'Unknown'], dtype=object)

# %%
def sexo(x):
    for i in x: 
        if i == 'M':
            return 'M'
        elif i == 'F':
            return 'F'
        else:
            return 'Unknown'

# %%
sexlst = list(sharkdf['Sex'])
sexlst
# Out:
# ['F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
# ...

# %%
sharkdf.Sex = sexo(sexlst)

# %%
sharkdf.Sex.unique()
# Out:
# array(['F'], dtype=object)

# %%
sharkdf.Sex
# Out:
# 0       F
# 8       F
# 13      F
# 18      F
# 21      F
#        ..
# 5273    F
# 5311    F
# 5375    F
# 5484    F
# 5545    F
# Name: Sex, Length: 1218, dtype: object

# %%
sharkdf.shape
# Out:
# (1560, 24)
