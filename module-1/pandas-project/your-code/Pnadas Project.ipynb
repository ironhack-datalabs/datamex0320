# %%
import pandas as pd
import numpy as np
import warnings 
warnings.simplefilter("ignore")

# %%
#importando bases de datos y convirtiendo a dataframe

sharkdf=pd.read_csv('attacks.csv', sep=',', encoding='latin-1')

sharkdf.shape
# Out:
# (25723, 24)

# %%
#Inspeccionando base de datos
sharkdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
sharkdf
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
sharkdf.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharkdf = sharkdf.rename(columns={'Species ': 'Species', 'Sex ': 'Sex', 'Fatal (Y/N)' : 'Fatal',
                                  'Investigator or Source': 'InvestigatorSource', 'href formula': 'hrefformula',
                                  'Case Number.1': 'CaseNumber.1', 'Case Number.2': 'CaseNumber.2', 
                                 'original order': 'originalorder', 'Unnamed: 22': 'Unnamed22', 'Unnamed: 23': 'Unnamed23', 'Case Number': 'CaseNumber'})
sharkdf.columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal', 'Time', 'Species',
#        'InvestigatorSource', 'pdf', 'hrefformula', 'href', 'CaseNumber.1',
#        'CaseNumber.2', 'originalorder', 'Unnamed22', 'Unnamed23'],
#       dtype='object')

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber            17021
# Date                  19421
# Year                  19423
# Type                  19425
# Country               19471
# Area                  19876
# Location              19961
# Activity              19965
# Name                  19631
# Sex                   19986
# Age                   22252
# Injury                19449
# Fatal                 19960
# Time                  22775
# Species               22259
# InvestigatorSource    19438
# pdf                   19421
# hrefformula           19422
# href                  19421
# CaseNumber.1          19421
# CaseNumber.2          19421
# originalorder         19414
# Unnamed22             25722
# Unnamed23             25721
# dtype: int64

# %%
sharkdf.T.shape
# Out:
# (24, 25723)

# %%
#Cuando transponemos la tabla, si la columna tiene más de la mitad de NaN no lo consideraremos.
MaxNa = 15
sharkdf=sharkdf.T.loc[:, (sharkdf.T.isnull().sum(axis=0) <= MaxNa)]

# %%
sharkdf=sharkdf.T

# %%
sharkdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CaseNumber          6301 non-null   object
#  1   Date                6302 non-null   object
#  2   Year                6300 non-null   object
#  3   Type                6298 non-null   object
#  4   Country             6252 non-null   object
#  5   Area                5847 non-null   object
#  6   Location            5762 non-null   object
#  7   Activity            5758 non-null   object
#  8   Name                6092 non-null   object
#  9   Sex                 5737 non-null   object
#  10  Age                 3471 non-null   object
#  11  Injury              6274 non-null   object
#  12  Fatal               5763 non-null   object
#  13  Time                2948 non-null   object
#  14  Species             3464 non-null   object
#  15  InvestigatorSource  6285 non-null   object
#  16  pdf                 6302 non-null   object
#  17  hrefformula         6301 non-null   object
#  18  href                6302 non-null   object
#  19  CaseNumber.1        6302 non-null   object
#  20  CaseNumber.2        6302 non-null   object
#  21  originalorder       6302 non-null   object
#  22  Unnamed22           1 non-null      object
#  23  Unnamed23           2 non-null      object
# dtypes: object(24)
# memory usage: 1.2+ MB

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber               1
# Date                     0
# Year                     2
# Type                     4
# Country                 50
# Area                   455
# Location               540
# Activity               544
# Name                   210
# Sex                    565
# Age                   2831
# Injury                  28
# Fatal                  539
# Time                  3354
# Species               2838
# InvestigatorSource      17
# pdf                      0
# hrefformula              1
# href                     0
# CaseNumber.1             0
# CaseNumber.2             0
# originalorder            0
# Unnamed22             6301
# Unnamed23             6300
# dtype: int64

# %%
sharkdf['Time']=sharkdf['Time'].fillna('Unknown')

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber               1
# Date                     0
# Year                     2
# Type                     4
# Country                 50
# Area                   455
# Location               540
# Activity               544
# Name                   210
# Sex                    565
# Age                   2831
# Injury                  28
# Fatal                  539
# Time                     0
# Species               2838
# InvestigatorSource      17
# pdf                      0
# hrefformula              1
# href                     0
# CaseNumber.1             0
# CaseNumber.2             0
# originalorder            0
# Unnamed22             6301
# Unnamed23             6300
# dtype: int64

# %%
sharkdf.Time.head(50)
# Out:
# 0              18h00
# 1      14h00  -15h00
# 2              07h45
# 3            Unknown
# 4            Unknown
# 5            Unknown
# 6     Late afternoon
# 7            Unknown
# 8              17h00
# 9              14h00
# 10           Morning
# 11           Unknown
# 12             15h00
# 13             08h15
# 14           Unknown
# 15             11h00
# 16             10h30
# 17           Unknown
# 18             10h40
# 19             16h50
# 20             07h00
# 21             09h30
# 22         Afternoon
# 23             21h50
# 24             09h40
# 25           Unknown
# 26           Unknown
# 27           Unknown
# 28           Unknown
# 29             08h00
# 30             09h30
# 31           Unknown
# 32             17h00
# 33             18h00
# 34             15h00
# 35             09h30
# 36             17h35
# 37             15h30
# 38             07h30
# 39           Unknown
# 40       19h00, Dusk
# 41             Night
# 42             16h00
# 43             18h00
# 44           Unknown
# 45           Unknown
# 46           Unknown
# 47             08h00
# 48             15h30
# 49             15h01
# Name: Time, dtype: object

# %%
import re
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('[a-zA-Z]','', x))

# %%
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub('-\d\d\d\d','', x))

# %%
sharkdf.Time=sharkdf.Time.apply(lambda x : re.sub(' ','', x))

# %%
sharkdf.Time.head(30)
# Out:
# 0     1800
# 1     1400
# 2     0745
# 3
# 4
# 5
# 6
# 7
# 8     1700
# 9     1400
# 10
# 11
# 12    1500
# 13    0815
# 14
# 15    1100
# 16    1030
# 17
# 18    1040
# 19    1650
# 20    0700
# 21    0930
# 22
# 23    2150
# 24    0940
# 25
# 26
# 27
# 28
# 29    0800
# Name: Time, dtype: object

# %%
sharkdf.Time.isnull().sum()
# Out:
# 0

# %%
sharkdf['Age']=sharkdf['Age'].fillna('Unknown')

# %%
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('[a-zA-Z]','', x))

# %%
sharkdf.Age=sharkdf.Age.apply(lambda x : re.sub('\d\d ','', x))

# %%
sharkdf.Age.tail(50)
# Out:
# 6252
# 6253
# 6254     50
# 6255
# 6256
# 6257
# 6258
# 6259
# 6260
# 6261
# 6262
# 6263
# 6264
# 6265     14
# 6266
# 6267
# 6268
# 6269
# 6270
# 6271
# 6272
# 6273
# 6274
# 6275
# 6276     16
# 6277
# 6278
# 6279
# 6280
# 6281
# 6282
# 6283
# 6284
# 6285
# 6286
# 6287
# 6288
# 6289
# 6290
# 6291
# 6292
# 6293
# 6294
# 6295
# 6296
# 6297
# 6298
# 6299
# 6300
# 6301     15
# Name: Age, dtype: object

# %%
sharkdf.Age.isnull().sum()
# Out:
# 0

# %%
sharkdf.YEAR=sharkdf.Date

sharkdf.YEAR
# Out:
# 0       25-Jun-2018
# 1       18-Jun-2018
# 2       09-Jun-2018
# 3       08-Jun-2018
# 4       04-Jun-2018
#            ...
# 6297    Before 1903
# 6298    Before 1903
# 6299      1900-1905
# 6300      1883-1889
# 6301      1845-1853
# Name: Date, Length: 6302, dtype: object

# %%
sharkdf.YEAR=sharkdf.YEAR.apply(lambda x : re.sub(r'(\d\d-\w\w\w.)', '',x))

# %%
sharkdf.YEAR=sharkdf.YEAR.apply(lambda x : re.sub(r'(\w\w\w\w\w\w\w\w )', '',x))

# %%
sharkdf.YEAR=sharkdf.YEAR.apply(lambda x : re.sub(r'(\w\w\w )', '',x))

# %%
sharkdf.YEAR=sharkdf.YEAR.apply(lambda x : re.sub(r'(\d-\w\w\w-)', '',x))

# %%
sharkdf.YEAR.head(50)
# Out:
# 0     2018
# 1     2018
# 2     2018
# 3     2018
# 4     2018
# 5     2018
# 6     2018
# 7     2018
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2018
# 13    2018
# 14    2018
# 15    2018
# 16    2018
# 17    2018
# 18    2018
# 19    2018
# 20    2018
# 21    2018
# 22    2018
# 23    2018
# 24    2018
# 25    2018
# 26    2018
# 27    2018
# 28    2018
# 29    2018
# 30    2018
# 31    2018
# 32    2018
# 33    2018
# 34    2018
# 35    2018
# 36    2018
# 37    2018
# 38    2018
# 39    2018
# 40    2018
# 41    2018
# 42    2018
# 43    2018
# 44    2018
# 45    2018
# 46    2018
# 47    2018
# 48    2018
# 49    2018
# Name: Date, dtype: object

# %%
sharkdf.YEAR.tail(50)
# Out:
# 6252                             Bef1958
# 6253                             Bef1957
# 6254                             Bef1957
# 6255                             Bef1956
# 6256                             Bef1956
# 6257                         BefMar-1956
# 6258                             Bef1952
# 6259                                  19
# 6260                         "Durwar" 19
# 6261                            "Befwar"
# 6262                 Sto be 19, mlik1945
# 6263                                  19
# 6264                                  19
# 6265                                  19
# 6266                             1- 1950
# 6267                             1- 1950
# 6268                             1- 1950
# 6269                                  19
# 6270                             Bef1905
# 6271                                WoII
# 6272                                WoII
# 6273                             Bef1905
# 6274                         A yebef1938
# 6275                             No date
# 6276                             Ea1930s
# 6277                             Bef1927
# 6278                         Betw1& 1939
# 6279                             No date
# 6280                             No date
# 6281                             No date
# 6282                              1-1923
# 6283                             Bef1921
# 6284                             Bef1911
# 6285                             Bef1921
# 6286                             Bef1921
# 6287                             Bef1917
# 6288                             Bef1916
# 6289    No d(3 dafpincident) & prto 1913
# 6290                             Bef1913
# 6291                             Bef1911
# 6292                              Ci1862
# 6293                             Bef1906
# 6294                             Bef1906
# 6295                             Bef1906
# 6296                             Bef1906
# 6297                             Bef1903
# 6298                             Bef1903
# 6299                                  19
# 6300                                  18
# 6301                                  18
# Name: Date, dtype: object

# %%
sharkdf.YEAR.head()
# Out:
# 0    25-Jun
# 1    18-Jun
# 2    09-Jun
# 3    08-Jun
# 4    04-Jun
# Name: Date, dtype: object

# %%
sharkdf.Date.head(50)
# Out:
# 0              25-Jun-2018
# 1              18-Jun-2018
# 2              09-Jun-2018
# 3              08-Jun-2018
# 4              04-Jun-2018
# 5              03-Jun-2018
# 6              03-Jun-2018
# 7              27-May-2018
# 8              26-May-2018
# 9              26-May-2018
# 10             24-May-2018
# 11             21-May-2018
# 12             13-May-2018
# 13             13-May-2018
# 14                May 2018
# 15             12-May-2018
# 16             09-May-2018
# 17    Reported 30-Apr-2018
# 18             28-Apr-2018
# 19             28-Apr-2018
# 20             25-Apr-2018
# 21             25-Apr-2018
# 22             24-Apr-2018
# 23             23-Apr-2018
# 24             22-Apr-2018
# 25             19-Apr-2018
# 26             15-Apr-2018
# 27             15-Apr-2018
# 28             15-Apr-2018
# 29             15-Apr-2018
# 30             14-Apr-2018
# 31    Reported 10-Apr-2018
# 32             09-Apr-2018
# 33             05-Apr-2018
# 34             03-Apr-2018
# 35             31-Mar-2018
# 36             14-Mar-2018
# 37              9-Mar-2018
# 38              9-Mar-2018
# 39             24-Feb-2018
# 40             23-Feb-2018
# 41             18-Feb-2018
# 42             15-Feb-2018
# 43             14-Feb-2018
# 44             11-Feb-2018
# 45             03-Feb-2018
# 46             01-Feb-2018
# 47             28-Jan-2018
# 48             21-Jan-2018
# 49             14-Jan-2018
# Name: Date, dtype: object

# %%
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\w\w\w\w\w\w\w\w ','', x))

# %%
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('-\d\d\d\d','', x))

# %%
sharkdf.Date=sharkdf.Date.apply(lambda x : re.sub('\w\w\w\w\w\w ','', x))

# %%
sharkdf.Species.head(50)
# Out:
# 0                                       White shark
# 1                                               NaN
# 2                                               NaN
# 3                                         2 m shark
# 4                                   Tiger shark, 3m
# 5                                               NaN
# 6                                       Tiger shark
# 7                                   Lemon shark, 3'
# 8                                    Bull shark, 6'
# 9                                               NaN
# 10                                  Grey reef shark
# 11                                              NaN
# 12                                              NaN
# 13                                 Invalid incident
# 14                            Tawny nurse shark, 2m
# 15                                              NaN
# 16                  Shark involvement not confirmed
# 17                                              NaN
# 18                                      Tiger shark
# 19                                              NaN
# 20                                     Questionable
# 21                                        3 m shark
# 22                               White shark, 3.5 m
# 23                                      Tiger shark
# 24                               White shark, 2.5 m
# 25                                         6' shark
# 26                              Juvenile bull shark
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 30                                      Tiger shark
# 31                  Shark involvement not confirmed
# 32                                        2 m shark
# 33                                       Bull shark
# 34                                      White shark
# 35                                 Tiger shark, 12'
# 36                                  Wobbegong shark
# 37                                      3.5 m shark
# 38                                      1.8 m shark
# 39                                   Blacktip shark
# 40              Juvenile white shark,  2.7 to 3.2 m
# 41                                              NaN
# 42                                  Bull shark, 2 m
# 43                             Possibly a wobbegong
# 44    Injury believed caused by an eel, not a shark
# 45                                 Galapagos shark?
# 46                                         2m shark
# 47                                       Bull shark
# 48                                 Bull shark, 3 m
# 49                             Grey reef shark. 2 m
# Name: Species, dtype: object

# %%
sharkdf['Species']=sharkdf['Species'].fillna('Unknown')

# %%
sharkdf=sharkdf.drop([31], axis=0)

# %%
sharkdf.Species.head(50)
# Out:
# 0                                       White shark
# 1                                           Unknown
# 2                                           Unknown
# 3                                         2 m shark
# 4                                   Tiger shark, 3m
# 5                                           Unknown
# 6                                       Tiger shark
# 7                                   Lemon shark, 3'
# 8                                    Bull shark, 6'
# 9                                           Unknown
# 10                                  Grey reef shark
# 11                                          Unknown
# 12                                          Unknown
# 13                                 Invalid incident
# 14                            Tawny nurse shark, 2m
# 15                                          Unknown
# 16                  Shark involvement not confirmed
# 17                                          Unknown
# 18                                      Tiger shark
# 19                                          Unknown
# 20                                     Questionable
# 21                                        3 m shark
# 22                               White shark, 3.5 m
# 23                                      Tiger shark
# 24                               White shark, 2.5 m
# 25                                         6' shark
# 26                              Juvenile bull shark
# 27                                          Unknown
# 28                                          Unknown
# 29                                          Unknown
# 30                                      Tiger shark
# 32                                        2 m shark
# 33                                       Bull shark
# 34                                      White shark
# 35                                 Tiger shark, 12'
# 36                                  Wobbegong shark
# 37                                      3.5 m shark
# 38                                      1.8 m shark
# 39                                   Blacktip shark
# 40              Juvenile white shark,  2.7 to 3.2 m
# 41                                          Unknown
# 42                                  Bull shark, 2 m
# 43                             Possibly a wobbegong
# 44    Injury believed caused by an eel, not a shark
# 45                                 Galapagos shark?
# 46                                         2m shark
# 47                                       Bull shark
# 48                                 Bull shark, 3 m
# 49                             Grey reef shark. 2 m
# 50                               White shark, 3.5 m
# Name: Species, dtype: object

# %%
sharkdf.isnull().sum()
# Out:
# CaseNumber               1
# Date                     0
# Year                     2
# Type                     4
# Country                 50
# Area                   455
# Location               540
# Activity               544
# Name                   210
# Sex                    565
# Age                      0
# Injury                  28
# Fatal                  539
# Time                     0
# Species                  0
# InvestigatorSource      17
# pdf                      0
# hrefformula              1
# href                     0
# CaseNumber.1             0
# CaseNumber.2             0
# originalorder            0
# Unnamed22             6300
# Unnamed23             6299
# dtype: int64

# %%
sharkdf.Date.head(50)
# Out:
# 0       25-Jun
# 1       18-Jun
# 2       09-Jun
# 3       08-Jun
# 4       04-Jun
# 5       03-Jun
# 6       03-Jun
# 7       27-May
# 8       26-May
# 9       26-May
# 10      24-May
# 11      21-May
# 12      13-May
# 13      13-May
# 14    May 2018
# 15      12-May
# 16      09-May
# 17      30-Apr
# 18      28-Apr
# 19      28-Apr
# 20      25-Apr
# 21      25-Apr
# 22      24-Apr
# 23      23-Apr
# 24      22-Apr
# 25      19-Apr
# 26      15-Apr
# 27      15-Apr
# 28      15-Apr
# 29      15-Apr
# 30      14-Apr
# 32      09-Apr
# 33      05-Apr
# 34      03-Apr
# 35      31-Mar
# 36      14-Mar
# 37       9-Mar
# 38       9-Mar
# 39      24-Feb
# 40      23-Feb
# 41      18-Feb
# 42      15-Feb
# 43      14-Feb
# 44      11-Feb
# 45      03-Feb
# 46      01-Feb
# 47      28-Jan
# 48      21-Jan
# 49      14-Jan
# 50      13-Jan
# Name: Date, dtype: object

# %%
sharkdf.Date.value_counts()
# Out:
# Aug                 37
# Jul                 31
# 02-Sep              31
# 27-Jul              31
# 29-Aug              31
#                     ..
# 11-Aug-              1
# 26-Jul.b             1
# 1950.07.19           1
# 07-Mar or 27-Mar     1
# 190Feb               1
# Name: Date, Length: 856, dtype: int64

# %%
sharkdf=sharkdf.drop(['Year'], axis=1)

# %%
sharkdf
# Out:
#       CaseNumber    Date        Type             Country               Area  \
# 0     2018.06.25  25-Jun     Boating                 USA         California
# 1     2018.06.18  18-Jun  Unprovoked                 USA            Georgia
# 2     2018.06.09  09-Jun     Invalid                 USA             Hawaii
# 3     2018.06.08  08-Jun  Unprovoked           AUSTRALIA    New South Wales
# 4     2018.06.04  04-Jun    Provoked              MEXICO             Colima
# ...          ...     ...         ...                 ...                ...
# 6297     ND.0005    1903  Unprovoked           AUSTRALIA  Western Australia
# 6298     ND.0004    1903  Unprovoked           AUSTRALIA  Western Australia
# 6299     ND.0003    1900  Unprovoked                 USA     North Carolina
# 6300     ND.0002    1883  Unprovoked              PANAMA                NaN
# 6301     ND.0001    1845  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0             Oceanside, San Diego County      Paddling
# 1          St. Simon Island, Glynn County      Standing
# 2                            Habush, Oahu       Surfing
# 3                      Arrawarra Headland       Surfing
# 4                                La Ticla   Free diving
# ...                                   ...           ...
# 6297                          Roebuck Bay        Diving
# 6298                                  NaN  Pearl diving
# 6299                       Ocracoke Inlet      Swimming
# 6300                 Panama Bay 8ºN, 79ºW           NaN
# 6301  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex Age  ...          Species  \
# 0               Julie Wolfe   F  57  ...      White shark
# 1           Adyson McNeely    F  11  ...          Unknown
# 2               John Denges   M  48  ...          Unknown
# 3                      male   M      ...        2 m shark
# 4            Gustavo Ramos    M      ...  Tiger shark, 3m
# ...                     ...  ..  ..  ...              ...
# 6297                   male   M      ...          Unknown
# 6298                  Ahmun   M      ...          Unknown
# 6299  Coast Guard personnel   M      ...          Unknown
# 6300        Jules Patterson   M      ...          Unknown
# 6301                   male   M  15  ...          Unknown
#
#                          InvestigatorSource                             pdf  \
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                             hrefformula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href CaseNumber.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
# ...                                                 ...          ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0001
#
#      CaseNumber.2 originalorder Unnamed22 Unnamed23
# 0      2018.06.25          6303       NaN       NaN
# 1      2018.06.18          6302       NaN       NaN
# 2      2018.06.09          6301       NaN       NaN
# 3      2018.06.08          6300       NaN       NaN
# 4      2018.06.04          6299       NaN       NaN
# ...           ...           ...       ...       ...
# 6297      ND.0005             6       NaN       NaN
# 6298      ND.0004             5       NaN       NaN
# 6299      ND.0003             4       NaN       NaN
# 6300      ND.0002             3       NaN       NaN
# 6301      ND.0001             2       NaN       NaN
#
# [6301 rows x 23 columns]

# %%
sharkdf.YEAR.tail(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-21d7eeb88f55> in <module>
# ----> 1 sharkdf.YEAR.tail(50)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'YEAR'

# %%
sharkdf.columns

# %%
sharkdf.Sex.head(50)

# %%
sharkdf.Sex.unique()
