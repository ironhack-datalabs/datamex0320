# %%
import json
import requests as req
import pandas as pd
from pandas.io.json import json_normalize

# %%
resp=req.get('https://app.ticketmaster.com/discovery/v2/events.json?apikey=VQCQj3wMhwp0EQeEw9mUft6KYw7lTw4I')
resp.status_code
# Out:
# 200

# %%
results = resp.json()
results
# Out:
# {'_embedded': {'events': [{'_embedded': {'attractions': [{'_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9174wRf?locale=en-us'}},
#        'classifications': [{'family': False,
#          'genre': {'id': 'KnvZfZ7v7l1', 'name': 'Theatre'},
#          'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7na', 'name': 'Arts & Theatre'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7vAve', 'name': 'Musical'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#          'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}}],
#        'id': 'K8vZ9174wRf',
#        'images': [{'fallback': False,
#          'height': 427,
#          'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/300/88bcb3d0-aa78-428d-ad10-52514ea72300_570131_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640},
#         {'fallback': False,
#          'height': 56,
#          'ratio': '16_9',
# ...

# %%
results.keys()
# Out:
# dict_keys(['_embedded', '_links', 'page'])

# %%
results['_embedded']['events']
# Out:
# [{'_embedded': {'attractions': [{'_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9174wRf?locale=en-us'}},
#      'classifications': [{'family': False,
#        'genre': {'id': 'KnvZfZ7v7l1', 'name': 'Theatre'},
#        'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7na', 'name': 'Arts & Theatre'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vAve', 'name': 'Musical'},
#        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}}],
#      'id': 'K8vZ9174wRf',
#      'images': [{'fallback': False,
#        'height': 427,
#        'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/300/88bcb3d0-aa78-428d-ad10-52514ea72300_570131_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640},
#       {'fallback': False,
#        'height': 56,
#        'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/300/88bcb3d0-aa78-428d-ad10-52514ea72300_570131_RECOMENDATION_16_9.jpg',
# ...

# %%
flattened_data = json_normalize(results)
flattened_data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                     _embedded.events  ... page.number
# 0  [{'name': 'Hamilton (Touring)', 'type': 'event...  ...           0
#
# [1 rows x 9 columns]

# %%
x=json_normalize(flattened_data['_embedded.events'][0])
x
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                   name  ...                              _embedded.attractions
# 0   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 1               Eagles  ...  [{'name': 'Eagles', 'type': 'attraction', 'id'...
# 2               Eagles  ...  [{'name': 'Eagles', 'type': 'attraction', 'id'...
# 3   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 4   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 5   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 6   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 7               Eagles  ...  [{'name': 'Eagles', 'type': 'attraction', 'id'...
# ...

# %%
x.describe
# Out:
# <bound method NDFrame.describe of                   name  ...                              _embedded.attractions
# 0   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 1               Eagles  ...  [{'name': 'Eagles', 'type': 'attraction', 'id'...
# 2               Eagles  ...  [{'name': 'Eagles', 'type': 'attraction', 'id'...
# 3   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 4   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 5   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 6   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 7               Eagles  ...  [{'name': 'Eagles', 'type': 'attraction', 'id'...
# 8   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# 9   Hamilton (Touring)  ...  [{'name': 'Hamilton (Touring)', 'type': 'attra...
# ...
