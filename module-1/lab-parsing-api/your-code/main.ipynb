# %% [markdown]
# # Challenge: Promotions
#
# Star Wars

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:

# %%
import json
import requests as req
import pandas as pd
from pandas.io.json import json_normalize
url = "https://swapi.co/api/people"

# %% [markdown]
# ## Reading the data

# %%
respuesta=req.get(url) #se establece la conexión
respuesta
# Out:
# <Response [200]>

# %%
results=respuesta.json() #se pasa a formato json

# %%
df_original=pd.DataFrame(results) #se pasa a data frame
df_original
# Out:
#    count                                 next previous  \
# 0     87  https://swapi.co/api/people/?page=2     None
# 1     87  https://swapi.co/api/people/?page=2     None
# 2     87  https://swapi.co/api/people/?page=2     None
# 3     87  https://swapi.co/api/people/?page=2     None
# 4     87  https://swapi.co/api/people/?page=2     None
# 5     87  https://swapi.co/api/people/?page=2     None
# 6     87  https://swapi.co/api/people/?page=2     None
# 7     87  https://swapi.co/api/people/?page=2     None
# 8     87  https://swapi.co/api/people/?page=2     None
# 9     87  https://swapi.co/api/people/?page=2     None
#
#                                              results
# 0  {'name': 'Luke Skywalker', 'height': '172', 'm...
# 1  {'name': 'C-3PO', 'height': '167', 'mass': '75...
# 2  {'name': 'R2-D2', 'height': '96', 'mass': '32'...
# 3  {'name': 'Darth Vader', 'height': '202', 'mass...
# 4  {'name': 'Leia Organa', 'height': '150', 'mass...
# ...

# %%
df = df_original.results.apply(pd.Series) #se extrae la información que me interesa

df
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                         homeworld  \
# 0      19BBY    male   https://swapi.co/api/planets/1/
# ...

# %%
df.height = df.height.astype(int)
df.mass = df.mass.astype(int)

# %%
df.dtypes
# Out:
# name          object
# height         int64
# mass           int64
# hair_color    object
# skin_color    object
# eye_color     object
# birth_year    object
# gender        object
# homeworld     object
# films         object
# species       object
# vehicles      object
# starships     object
# created       object
# edited        object
# url           object
# dtype: object

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The tallest
#
# * The shortest
#
# * The heaviest
#
# * The lightest

# %% [markdown]
# ## Tallest

# %%
df[df.height == df.height.max()]
# Out:
#           name  height  mass hair_color skin_color eye_color birth_year  \
# 3  Darth Vader     202   136       none      white    yellow    41.9BBY
#
#   gender                        homeworld  \
# 3   male  https://swapi.co/api/planets/1/
#
#                                                films  \
# 3  [https://swapi.co/api/films/2/, https://swapi....
#
#                              species vehicles  \
# 3  [https://swapi.co/api/species/1/]       []
#
#                               starships                      created  \
# 3  [https://swapi.co/api/starships/13/]  2014-12-10T15:18:20.704000Z
#
#                         edited                             url
# 3  2014-12-20T21:17:50.313000Z  https://swapi.co/api/people/4/

# %% [markdown]
# ## Shortest

# %%
df[df.height == df.height.min()]
# Out:
#     name  height  mass hair_color   skin_color eye_color birth_year gender  \
# 2  R2-D2      96    32        n/a  white, blue       red      33BBY    n/a
#
#                          homeworld  \
# 2  https://swapi.co/api/planets/8/
#
#                                                films  \
# 2  [https://swapi.co/api/films/2/, https://swapi....
#
#                              species vehicles starships  \
# 2  [https://swapi.co/api/species/2/]       []        []
#
#                        created                       edited  \
# 2  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
#
#                               url
# 2  https://swapi.co/api/people/3/

# %% [markdown]
# ## Heaviest

# %%
df[df.mass == df.mass.max()]
# Out:
#           name  height  mass hair_color skin_color eye_color birth_year  \
# 3  Darth Vader     202   136       none      white    yellow    41.9BBY
#
#   gender                        homeworld  \
# 3   male  https://swapi.co/api/planets/1/
#
#                                                films  \
# 3  [https://swapi.co/api/films/2/, https://swapi....
#
#                              species vehicles  \
# 3  [https://swapi.co/api/species/1/]       []
#
#                               starships                      created  \
# 3  [https://swapi.co/api/starships/13/]  2014-12-10T15:18:20.704000Z
#
#                         edited                             url
# 3  2014-12-20T21:17:50.313000Z  https://swapi.co/api/people/4/

# %% [markdown]
# ## Lightest

# %%
df[df.mass == df.mass.min()]
# Out:
#     name  height  mass hair_color   skin_color eye_color birth_year gender  \
# 2  R2-D2      96    32        n/a  white, blue       red      33BBY    n/a
# 7  R5-D4      97    32        n/a   white, red       red    unknown    n/a
#
#                          homeworld  \
# 2  https://swapi.co/api/planets/8/
# 7  https://swapi.co/api/planets/1/
#
#                                                films  \
# 2  [https://swapi.co/api/films/2/, https://swapi....
# 7                    [https://swapi.co/api/films/1/]
#
#                              species vehicles starships  \
# 2  [https://swapi.co/api/species/2/]       []        []
# 7  [https://swapi.co/api/species/2/]       []        []
#
#                        created                       edited  \
# 2  2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 7  2014-12-10T15:57:50.959000Z  2014-12-20T21:17:50.321000Z
#
#                               url
# 2  https://swapi.co/api/people/3/
# 7  https://swapi.co/api/people/8/
