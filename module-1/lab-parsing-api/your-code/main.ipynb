# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import requests as req
import sys
import pandas as pd
from pandas.io.json import json_normalize

# %%
resp=req.get("https://api.covid19api.com/summary")

resp.text
# Out:
# '{"Global":{"NewConfirmed":72611,"TotalConfirmed":1341327,"NewDeaths":5191,"TotalDeaths":74520,"NewRecovered":16507,"TotalRecovered":275564},"Countries":[{"Country":"ALA Aland Islands","CountryCode":"AX","Slug":"ala-aland-islands","NewConfirmed":0,"TotalConfirmed":0,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2020-04-07T06:43:18Z"},{"Country":"Afghanistan","CountryCode":"AF","Slug":"afghanistan","NewConfirmed":18,"TotalConfirmed":367,"NewDeaths":4,"TotalDeaths":11,"NewRecovered":3,"TotalRecovered":18,"Date":"2020-04-07T06:43:18Z"},{"Country":"Albania","CountryCode":"AL","Slug":"albania","NewConfirmed":16,"TotalConfirmed":377,"NewDeaths":1,"TotalDeaths":21,"NewRecovered":12,"TotalRecovered":116,"Date":"2020-04-07T06:43:18Z"},{"Country":"Algeria","CountryCode":"DZ","Slug":"algeria","NewConfirmed":103,"TotalConfirmed":1423,"NewDeaths":21,"TotalDeaths":173,"NewRecovered":0,"TotalRecovered":90,"Date":"2020-04-07T06:43:18Z"},{"Country":"American Samoa","CountryCode":"AS","Slug":"american-samoa","NewConfirmed":0,"TotalConfirmed":0,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2020-04-07T06:43:18Z"},{"Country":"Andorra","CountryCode":"AD","Slug":"andorra","NewConfirmed":24,"TotalConfirmed":525,"NewDeaths":3,"TotalDeaths":21,"NewRecovered":5,"TotalRecovered":31,"Date":"2020-04-07T06:43:18Z"},{"Country":"Angola","CountryCode":"AO","Slug":"angola","NewConfirmed":2,"TotalConfirmed":16,"NewDeaths":0,"TotalDeaths":2,"NewRecovered":0,"TotalRecovered":2,"Date":"2020-04-07T06:43:18Z"},{"Country":"Anguilla","CountryCode":"AI","Slug":"anguilla","NewConfirmed":0,"TotalConfirmed":0,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2020-04-07T06:43:18Z"},{"Country":"Antarctica","CountryCode":"AQ","Slug":"antarctica","NewConfirmed":0,"TotalConfirmed":0,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2020-04-07T06:43:18Z"},{"Country":"Antigua and Barbuda","CountryCode":"AG","Slug":"antigua-and-barbuda","NewConfirmed":0,"TotalConfirmed":15,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2020-04-07T06:43:18Z"},{"Country":"Argentina","CountryCode":"AR","Slug":"argentina","NewConfirmed":103,"TotalConfirmed":1554,"NewDeaths":4,"TotalDeaths":48,"NewRecovered":45,"TotalRecovered":325,"Date":"2020-04-07T06:43:18Z"},{"Country":"Armenia","CountryCode":"AM","Slug":"armenia","NewConfirmed":11,"TotalConfirmed":833,"NewDeaths":1,"TotalDeaths":8,"NewRecovered":5,"TotalRecovered":62,"Date":"2020-04-07T06:43:18Z"},{"Country":"Aruba","CountryCode":"AW","Slug":"aruba","NewConfirmed":0,"TotalConfirmed":0,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2020-04-07T06:43:18Z"},{"Country":"Australia","CountryCode":"AU","Slug":"australia","NewConfirmed":110,"TotalConfirmed":5797,"NewDeaths":5,"TotalDeaths":40,"NewRecovered":323,"TotalRecovered":1080,"Date":"2020-04-07T06:43:18Z"},{"Country":"Austria","CountryCode":"AT","Slug":"austria","NewConfirmed":246,"TotalConfirmed":12297,"NewDeaths":16,"TotalDeaths":220,"NewRecovered":465,"TotalRecovered":3463,"Date":"2020-04-07T06:43:18Z"},{"Country":"Azerbaijan","CountryCode":"AZ","Slug":"azerbaijan","NewConfirmed":57,"TotalConfirmed":641,"NewDeaths":0,"TotalDeaths":7,"NewRecovered":12,"TotalRecovered":44,"Date":"2020-04-07T06:43:18Z"},{"Country":"Bahamas","CountryCode":"BS","Slug":"bahamas","NewConfirmed":1,"TotalConfirmed":29,"NewDeaths":1,"TotalDeaths":5,"NewRecovered":4,"TotalRecovered":4,"Date":"2020-04-07T06:43:18Z"},{"Country":"Bahrain","CountryCode":"BH","Slug":"bahrain","NewConfirmed":56,"TotalConfirmed":756,"NewDeaths":0,"TotalDeaths":4,"NewRecovered":27,"TotalRecovered":458,"Date":"2020-04-07T06:43:18Z"},{"Country":"Bangladesh","CountryCode":"BD","Slug":"bangladesh","NewConfirmed":35,"TotalConfirmed":123,"NewDeaths":3,"TotalDeaths":12,"NewRecovered":0,"TotalRecovered":33,"Date":"2020-04-07T06:43:18Z"},{"Country":"Barbados","CountryCode":"BB","Slug":"barbados","NewCo ...

# %%
resp.status_code
# Out:
# 200

# %%
type(resp.text)
# Out:
# str

# %%
type(resp.content)
# Out:
# bytes

# %%
results=resp.json()

# %%
df=pd.json_normalize(results)

# %%
df= pd.DataFrame(df)

df
# Out:
#                                            Countries                  Date  \
# 0  [{'Country': 'ALA Aland Islands', 'CountryCode...  2020-04-07T06:43:18Z
#
#    Global.NewConfirmed  Global.TotalConfirmed  Global.NewDeaths  \
# 0                72611                1341327              5191
#
#    Global.TotalDeaths  Global.NewRecovered  Global.TotalRecovered
# 0               74520                16507                 275564

# %%
df = pd.json_normalize(df["Countries"][0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         244 non-null    object
#  1   CountryCode     244 non-null    object
#  2   Slug            244 non-null    object
#  3   NewConfirmed    244 non-null    int64
#  4   TotalConfirmed  244 non-null    int64
#  5   NewDeaths       244 non-null    int64
#  6   TotalDeaths     244 non-null    int64
#  7   NewRecovered    244 non-null    int64
#  8   TotalRecovered  244 non-null    int64
#  9   Date            244 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 19.2+ KB

# %%
df
# Out:
#                        Country CountryCode                       Slug  \
# 0            ALA Aland Islands          AX          ala-aland-islands
# 1                  Afghanistan          AF                afghanistan
# 2                      Albania          AL                    albania
# 3                      Algeria          DZ                    algeria
# 4               American Samoa          AS             american-samoa
# ..                         ...         ...                        ...
# 239  Wallis and Futuna Islands          WF  wallis-and-futuna-islands
# 240             Western Sahara          EH             western-sahara
# 241                      Yemen          YE                      yemen
# 242                     Zambia          ZM                     zambia
# 243                   Zimbabwe          ZW                   zimbabwe
#
#      NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0               0               0          0            0             0
# 1              18             367          4           11             3
# 2              16             377          1           21            12
# 3             103            1423         21          173             0
# 4               0               0          0            0             0
# ..            ...             ...        ...          ...           ...
# 239             0               0          0            0             0
# 240             0               4          0            0             0
# 241             0               0          0            0             0
# 242             0              39          0            1             2
# 243             1              10          0            1             0
#
#      TotalRecovered                  Date
# 0                 0  2020-04-07T06:43:18Z
# 1                18  2020-04-07T06:43:18Z
# 2               116  2020-04-07T06:43:18Z
# 3                90  2020-04-07T06:43:18Z
# 4                 0  2020-04-07T06:43:18Z
# ..              ...                   ...
# 239               0  2020-04-07T06:43:18Z
# 240               0  2020-04-07T06:43:18Z
# 241               0  2020-04-07T06:43:18Z
# 242               5  2020-04-07T06:43:18Z
# 243               0  2020-04-07T06:43:18Z
#
# [244 rows x 10 columns]

# %%
df.shape
# Out:
# (244, 10)

# %%
df.NewConfirmed
# Out:
# 0        0
# 1       18
# 2       16
# 3      103
# 4        0
#       ...
# 239      0
# 240      0
# 241      0
# 242      0
# 243      1
# Name: NewConfirmed, Length: 244, dtype: int64

# %%
df.describe()
# Out:
#        NewConfirmed  TotalConfirmed    NewDeaths   TotalDeaths  NewRecovered  \
# count    244.000000      244.000000   244.000000    244.000000    244.000000
# mean     297.586066     5497.241803    21.274590    305.409836     67.651639
# std     1993.824993    28727.121190   114.291458   1685.022547    378.789720
# min        0.000000        0.000000     0.000000      0.000000      0.000000
# 25%        0.000000        0.000000     0.000000      0.000000      0.000000
# 50%        2.000000       58.000000     0.000000      1.000000      0.000000
# 75%       52.250000      873.500000     2.000000     19.500000      6.250000
# max    29542.000000   366607.000000  1164.000000  16523.000000   4500.000000
#
#        TotalRecovered
# count      244.000000
# mean      1129.360656
# std       6440.597632
# min          0.000000
# 25%          0.000000
# 50%          4.000000
# 75%         75.000000
# max      77310.000000

# %%
df['Mortalidad']=df.TotalConfirmed/df.TotalDeaths

# %%
df
# Out:
#                        Country CountryCode                       Slug  \
# 0            ALA Aland Islands          AX          ala-aland-islands
# 1                  Afghanistan          AF                afghanistan
# 2                      Albania          AL                    albania
# 3                      Algeria          DZ                    algeria
# 4               American Samoa          AS             american-samoa
# ..                         ...         ...                        ...
# 239  Wallis and Futuna Islands          WF  wallis-and-futuna-islands
# 240             Western Sahara          EH             western-sahara
# 241                      Yemen          YE                      yemen
# 242                     Zambia          ZM                     zambia
# 243                   Zimbabwe          ZW                   zimbabwe
#
#      NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0               0               0          0            0             0
# 1              18             367          4           11             3
# 2              16             377          1           21            12
# 3             103            1423         21          173             0
# 4               0               0          0            0             0
# ..            ...             ...        ...          ...           ...
# 239             0               0          0            0             0
# 240             0               4          0            0             0
# 241             0               0          0            0             0
# 242             0              39          0            1             2
# 243             1              10          0            1             0
#
#      TotalRecovered                  Date  Mortalidad
# 0                 0  2020-04-07T06:43:18Z         NaN
# 1                18  2020-04-07T06:43:18Z   33.363636
# 2               116  2020-04-07T06:43:18Z   17.952381
# 3                90  2020-04-07T06:43:18Z    8.225434
# 4                 0  2020-04-07T06:43:18Z         NaN
# ..              ...                   ...         ...
# 239               0  2020-04-07T06:43:18Z         NaN
# 240               0  2020-04-07T06:43:18Z         inf
# 241               0  2020-04-07T06:43:18Z         NaN
# 242               5  2020-04-07T06:43:18Z   39.000000
# 243               0  2020-04-07T06:43:18Z   10.000000
#
# [244 rows x 11 columns]

# %%
df['Mortalidad']=df['Mortalidad'].fillna(0)
df.Mortalidad.head(50)
# Out:
# 0       0.000000
# 1      33.363636
# 2      17.952381
# 3       8.225434
# 4       0.000000
# 5      25.000000
# 6       8.000000
# 7       0.000000
# 8       0.000000
# 9            inf
# 10     32.375000
# 11    104.125000
# 12      0.000000
# 13    144.925000
# 14     55.895455
# 15     91.571429
# 16      5.800000
# 17    189.000000
# 18     10.250000
# 19     30.000000
# 20     53.846154
# 21     12.753676
# 22      7.000000
# 23     26.000000
# 24      0.000000
# 25           inf
# 26     16.636364
# 27     23.241379
# 28      6.000000
# 29      0.000000
# 30     21.562057
# 31      0.000000
# 32      0.000000
# 33    135.000000
# 34     24.954545
# 35     20.222222
# 36           inf
# 37           inf
# 38     73.111111
# 39     49.002959
# 40      7.000000
# 41      0.000000
# 42           inf
# 43           inf
# 44    130.135135
# 45     24.787106
# 46      0.000000
# 47      0.000000
# 48     34.326087
# 49      0.000000
# Name: Mortalidad, dtype: float64

# %%
total_rec=df.groupby(['TotalRecovered']).sum()

# %%
total_rec
# Out:
#                 NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  \
# TotalRecovered
# 0                        304            2481          8           64
# 1                         25             450          1           13
# 2                         39             387          1           24
# 3                          3              70          0            4
# 4                         24             423          3           14
# ...                      ...             ...        ...          ...
# 22837                   3599          132547        636        16523
# 24236                   2274           60500        136         3739
# 28700                   3251          103374        226         1810
# 40437                   5029          136675        700        13341
# 77310                     63           82665          2         3335
#
#                 NewRecovered
# TotalRecovered
# 0                          0
# 1                          3
# 2                          0
# 3                          2
# 4                          9
# ...                      ...
# 22837                   1022
# 24236                   4500
# 28700                      0
# 40437                   2357
# 77310                    103
#
# [99 rows x 5 columns]

# %%
total_rec.sort_values(by=['TotalRecovered'],
                      axis=0,
                      ascending=False,
                      inplace=False)
# Out:
#                 NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  \
# TotalRecovered
# 77310                     63           82665          2         3335
# 40437                   5029          136675        700        13341
# 28700                   3251          103374        226         1810
# 24236                   2274           60500        136         3739
# 22837                   3599          132547        636        16523
# ...                      ...             ...        ...          ...
# 4                         24             423          3           14
# 3                          3              70          0            4
# 2                         39             387          1           24
# 1                         25             450          1           13
# 0                        304            2481          8           64
#
#                 NewRecovered
# TotalRecovered
# 77310                    103
# 40437                   2357
# 28700                      0
# 24236                   4500
# 22837                   1022
# ...                      ...
# 4                          9
# 3                          2
# 2                          0
# 1                          3
# 0                          0
#
# [99 rows x 5 columns]

# %%
query={'limit':3, 'offset':1}
res=req.get('https://api.covid19api.com/summary', params=query)
res.json()
# Out:
# {'Global': {'NewConfirmed': 72611,
#   'TotalConfirmed': 1341327,
#   'NewDeaths': 5191,
#   'TotalDeaths': 74520,
#   'NewRecovered': 16507,
#   'TotalRecovered': 275564},
#  'Countries': [{'Country': 'ALA Aland Islands',
#    'CountryCode': 'AX',
#    'Slug': 'ala-aland-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 18,
#    'TotalConfirmed': 367,
#    'NewDeaths': 4,
#    'TotalDeaths': 11,
#    'NewRecovered': 3,
#    'TotalRecovered': 18,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 377,
#    'NewDeaths': 1,
#    'TotalDeaths': 21,
#    'NewRecovered': 12,
#    'TotalRecovered': 116,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 103,
#    'TotalConfirmed': 1423,
#    'NewDeaths': 21,
#    'TotalDeaths': 173,
#    'NewRecovered': 0,
#    'TotalRecovered': 90,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'American Samoa',
#    'CountryCode': 'AS',
#    'Slug': 'american-samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 525,
#    'NewDeaths': 3,
#    'TotalDeaths': 21,
#    'NewRecovered': 5,
#    'TotalRecovered': 31,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Anguilla',
#    'CountryCode': 'AI',
#    'Slug': 'anguilla',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 103,
#    'TotalConfirmed': 1554,
#    'NewDeaths': 4,
#    'TotalDeaths': 48,
#    'NewRecovered': 45,
#    'TotalRecovered': 325,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 833,
#    'NewDeaths': 1,
#    'TotalDeaths': 8,
#    'NewRecovered': 5,
#    'TotalRecovered': 62,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Aruba',
#    'CountryCode': 'AW',
#    'Slug': 'aruba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 110,
#    'TotalConfirmed': 5797,
#    'NewDeaths': 5,
#    'TotalDeaths': 40,
#    'NewRecovered': 323,
#    'TotalRecovered': 1080,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 246,
#    'TotalConfirmed': 12297,
#    'NewDeaths': 16,
#    'TotalDeaths': 220,
#    'NewRecovered': 465,
#    'TotalRecovered': 3463,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 57,
#    'TotalConfirmed': 641,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 12,
#    'TotalRecovered': 44,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 29,
#    'NewDeaths': 1,
#    'TotalDeaths': 5,
#    'NewRecovered': 4,
#    'TotalRecovered': 4,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 56,
#    'TotalConfirmed': 756,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 27,
#    'TotalRecovered': 458,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 123,
#    'NewDeaths': 3,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 33,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 60,
#    'NewDeaths': 1,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 138,
#    'TotalConfirmed': 700,
#    'NewDeaths': 5,
#    'TotalDeaths': 13,
#    'NewRecovered': 1,
#    'TotalRecovered': 53,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 1123,
#    'TotalConfirmed': 20814,
#    'NewDeaths': 185,
#    'TotalDeaths': 1632,
#    'NewRecovered': 235,
#    'TotalRecovered': 3986,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 7,
#    'NewDeaths': 1,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 26,
#    'NewDeaths': 1,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bermuda',
#    'CountryCode': 'BM',
#    'Slug': 'bermuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 183,
#    'NewDeaths': 1,
#    'TotalDeaths': 11,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 674,
#    'NewDeaths': 6,
#    'TotalDeaths': 29,
#    'NewRecovered': 17,
#    'TotalRecovered': 47,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bouvet Island',
#    'CountryCode': 'BV',
#    'Slug': 'bouvet-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 1031,
#    'TotalConfirmed': 12161,
#    'NewDeaths': 78,
#    'TotalDeaths': 564,
#    'NewRecovered': 0,
#    'TotalRecovered': 127,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'British Indian Ocean Territory',
#    'CountryCode': 'IO',
#    'Slug': 'british-indian-ocean-territory',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'British Virgin Islands',
#    'CountryCode': 'VG',
#    'Slug': 'british-virgin-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 135,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 9,
#    'TotalRecovered': 82,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 18,
#    'TotalConfirmed': 549,
#    'NewDeaths': 2,
#    'TotalDeaths': 22,
#    'NewRecovered': 2,
#    'TotalRecovered': 39,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 364,
#    'NewDeaths': 1,
#    'TotalDeaths': 18,
#    'NewRecovered': 18,
#    'TotalRecovered': 108,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 114,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 3,
#    'TotalRecovered': 53,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 658,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 17,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 807,
#    'TotalConfirmed': 16563,
#    'NewDeaths': 80,
#    'TotalDeaths': 338,
#    'NewRecovered': 244,
#    'TotalRecovered': 3256,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 1,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cayman Islands',
#    'CountryCode': 'KY',
#    'Slug': 'cayman-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 344,
#    'TotalConfirmed': 4815,
#    'NewDeaths': 3,
#    'TotalDeaths': 37,
#    'NewRecovered': 110,
#    'TotalRecovered': 728,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 63,
#    'TotalConfirmed': 82665,
#    'NewDeaths': 2,
#    'TotalDeaths': 3335,
#    'NewRecovered': 103,
#    'TotalRecovered': 77310,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Christmas Island',
#    'CountryCode': 'CX',
#    'Slug': 'christmas-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cocos (Keeling) Islands',
#    'CountryCode': 'CC',
#    'Slug': 'cocos-keeling-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 94,
#    'TotalConfirmed': 1579,
#    'NewDeaths': 11,
#    'TotalDeaths': 46,
#    'NewRecovered': 0,
#    'TotalRecovered': 88,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 45,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 161,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 2,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cook Islands',
#    'CountryCode': 'CK',
#    'Slug': 'cook-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 467,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 2,
#    'TotalRecovered': 18,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 40,
#    'TotalConfirmed': 1222,
#    'NewDeaths': 1,
#    'TotalDeaths': 16,
#    'NewRecovered': 5,
#    'TotalRecovered': 130,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 30,
#    'TotalConfirmed': 350,
#    'NewDeaths': 1,
#    'TotalDeaths': 9,
#    'NewRecovered': 3,
#    'TotalRecovered': 18,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 465,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 8,
#    'TotalRecovered': 45,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 235,
#    'TotalConfirmed': 4822,
#    'NewDeaths': 11,
#    'TotalDeaths': 78,
#    'NewRecovered': 25,
#    'TotalRecovered': 121,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 62,
#    'TotalConfirmed': 323,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 4,
#    'TotalRecovered': 41,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 314,
#    'TotalConfirmed': 4875,
#    'NewDeaths': 8,
#    'TotalDeaths': 187,
#    'NewRecovered': 60,
#    'TotalRecovered': 1489,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 90,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 9,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 1,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 83,
#    'TotalConfirmed': 1828,
#    'NewDeaths': 4,
#    'TotalDeaths': 86,
#    'NewRecovered': 16,
#    'TotalRecovered': 33,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 101,
#    'TotalConfirmed': 3747,
#    'NewDeaths': 11,
#    'TotalDeaths': 191,
#    'NewRecovered': 0,
#    'TotalRecovered': 100,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 149,
#    'TotalConfirmed': 1322,
#    'NewDeaths': 7,
#    'TotalDeaths': 85,
#    'NewRecovered': 12,
#    'TotalRecovered': 259,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 69,
#    'NewDeaths': 1,
#    'TotalDeaths': 4,
#    'NewRecovered': 3,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 2,
#    'TotalRecovered': 3,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 31,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 1108,
#    'NewDeaths': 4,
#    'TotalDeaths': 19,
#    'NewRecovered': 0,
#    'TotalRecovered': 62,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 44,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Falkland Islands (Malvinas)',
#    'CountryCode': 'FK',
#    'Slug': 'falkland-islands-malvinas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Faroe Islands',
#    'CountryCode': 'FO',
#    'Slug': 'faroe-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 14,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 5190,
#    'TotalConfirmed': 98963,
#    'NewDeaths': 833,
#    'TotalDeaths': 8926,
#    'NewRecovered': 1079,
#    'TotalRecovered': 17428,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'French Guiana',
#    'CountryCode': 'GF',
#    'Slug': 'french-guiana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'French Polynesia',
#    'CountryCode': 'PF',
#    'Slug': 'french-polynesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'French Southern Territories',
#    'CountryCode': 'TF',
#    'Slug': 'french-southern-territories',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 188,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 3,
#    'TotalRecovered': 39,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 3251,
#    'TotalConfirmed': 103374,
#    'NewDeaths': 226,
#    'TotalDeaths': 1810,
#    'NewRecovered': 0,
#    'TotalRecovered': 28700,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 214,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 31,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Gibraltar',
#    'CountryCode': 'GI',
#    'Slug': 'gibraltar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 20,
#    'TotalConfirmed': 1755,
#    'NewDeaths': 6,
#    'TotalDeaths': 79,
#    'NewRecovered': 191,
#    'TotalRecovered': 269,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Greenland',
#    'CountryCode': 'GL',
#    'Slug': 'greenland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guadeloupe',
#    'CountryCode': 'GP',
#    'Slug': 'guadeloupe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guam',
#    'CountryCode': 'GU',
#    'Slug': 'guam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 70,
#    'NewDeaths': 1,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 15,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guernsey',
#    'CountryCode': 'GG',
#    'Slug': 'guernsey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 128,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 31,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 8,
#    'TotalRecovered': 8,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Heard and Mcdonald Islands',
#    'CountryCode': 'HM',
#    'Slug': 'heard-and-mcdonald-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 30,
#    'TotalConfirmed': 298,
#    'NewDeaths': 0,
#    'TotalDeaths': 22,
#    'NewRecovered': 0,
#    'TotalRecovered': 6,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Hong Kong, SAR China',
#    'CountryCode': 'HK',
#    'Slug': 'hong-kong-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 744,
#    'NewDeaths': 4,
#    'TotalDeaths': 38,
#    'NewRecovered': 1,
#    'TotalRecovered': 67,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 76,
#    'TotalConfirmed': 1562,
#    'NewDeaths': 2,
#    'TotalDeaths': 6,
#    'NewRecovered': 32,
#    'TotalRecovered': 460,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 1190,
#    'TotalConfirmed': 4778,
#    'NewDeaths': 37,
#    'TotalDeaths': 136,
#    'NewRecovered': 146,
#    'TotalRecovered': 375,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 218,
#    'TotalConfirmed': 2491,
#    'NewDeaths': 11,
#    'TotalDeaths': 209,
#    'NewRecovered': 28,
#    'TotalRecovered': 192,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 2274,
#    'TotalConfirmed': 60500,
#    'NewDeaths': 136,
#    'TotalDeaths': 3739,
#    'NewRecovered': 4500,
#    'TotalRecovered': 24236,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 70,
#    'TotalConfirmed': 1031,
#    'NewDeaths': 3,
#    'TotalDeaths': 64,
#    'NewRecovered': 65,
#    'TotalRecovered': 344,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 370,
#    'TotalConfirmed': 5364,
#    'NewDeaths': 16,
#    'TotalDeaths': 174,
#    'NewRecovered': 0,
#    'TotalRecovered': 25,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Isle of Man',
#    'CountryCode': 'IM',
#    'Slug': 'isle-of-man',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 474,
#    'TotalConfirmed': 8904,
#    'NewDeaths': 8,
#    'TotalDeaths': 57,
#    'NewRecovered': 108,
#    'TotalRecovered': 585,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 3599,
#    'TotalConfirmed': 132547,
#    'NewDeaths': 636,
#    'TotalDeaths': 16523,
#    'NewRecovered': 1022,
#    'TotalRecovered': 22837,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 58,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 515,
#    'TotalConfirmed': 3654,
#    'NewDeaths': 8,
#    'TotalDeaths': 85,
#    'NewRecovered': 61,
#    'TotalRecovered': 575,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Jersey',
#    'CountryCode': 'JE',
#    'Slug': 'jersey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 349,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 16,
#    'TotalRecovered': 126,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 78,
#    'TotalConfirmed': 662,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 4,
#    'TotalRecovered': 46,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 16,
#    'TotalConfirmed': 158,
#    'NewDeaths': 2,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Korea (North)',
#    'CountryCode': 'KP',
#    'Slug': 'korea-north',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 47,
#    'TotalConfirmed': 10284,
#    'NewDeaths': 3,
#    'TotalDeaths': 186,
#    'NewRecovered': 135,
#    'TotalRecovered': 6598,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 109,
#    'TotalConfirmed': 665,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 4,
#    'TotalRecovered': 103,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 216,
#    'NewDeaths': 3,
#    'TotalDeaths': 4,
#    'NewRecovered': 24,
#    'TotalRecovered': 33,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 542,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 15,
#    'TotalRecovered': 16,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 541,
#    'NewDeaths': 1,
#    'TotalDeaths': 19,
#    'NewRecovered': 6,
#    'TotalRecovered': 60,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 14,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 1,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 77,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 55,
#    'TotalRecovered': 55,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 32,
#    'TotalConfirmed': 843,
#    'NewDeaths': 2,
#    'TotalDeaths': 15,
#    'NewRecovered': 1,
#    'TotalRecovered': 8,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 39,
#    'TotalConfirmed': 2843,
#    'NewDeaths': 5,
#    'TotalDeaths': 41,
#    'NewRecovered': 0,
#    'TotalRecovered': 500,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Macao, SAR China',
#    'CountryCode': 'MO',
#    'Slug': 'macao-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 15,
#    'TotalConfirmed': 570,
#    'NewDeaths': 5,
#    'TotalDeaths': 23,
#    'NewRecovered': 7,
#    'TotalRecovered': 30,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 82,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 5,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 131,
#    'TotalConfirmed': 3793,
#    'NewDeaths': 1,
#    'TotalDeaths': 62,
#    'NewRecovered': 236,
#    'TotalRecovered': 1241,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 13,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 47,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 8,
#    'TotalRecovered': 9,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 241,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Martinique',
#    'CountryCode': 'MQ',
#    'Slug': 'martinique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 244,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 7,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mayotte',
#    'CountryCode': 'YT',
#    'Slug': 'mayotte',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 253,
#    'TotalConfirmed': 2143,
#    'NewDeaths': 15,
#    'TotalDeaths': 94,
#    'NewRecovered': 0,
#    'TotalRecovered': 633,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 101,
#    'TotalConfirmed': 965,
#    'NewDeaths': 4,
#    'TotalDeaths': 19,
#    'NewRecovered': 7,
#    'TotalRecovered': 37,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 77,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 1,
#    'TotalRecovered': 4,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 15,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 233,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Montserrat',
#    'CountryCode': 'MS',
#    'Slug': 'montserrat',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 99,
#    'TotalConfirmed': 1120,
#    'NewDeaths': 10,
#    'TotalDeaths': 80,
#    'NewRecovered': 5,
#    'TotalRecovered': 81,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 22,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Nauru',
#    'CountryCode': 'NR',
#    'Slug': 'nauru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 973,
#    'TotalConfirmed': 18926,
#    'NewDeaths': 103,
#    'TotalDeaths': 1874,
#    'NewRecovered': 1,
#    'TotalRecovered': 258,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Netherlands Antilles',
#    'CountryCode': 'AN',
#    'Slug': 'netherlands-antilles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'New Caledonia',
#    'CountryCode': 'NC',
#    'Slug': 'new-caledonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 67,
#    'TotalConfirmed': 1106,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 20,
#    'TotalRecovered': 176,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 253,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 13,
#    'TotalRecovered': 26,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 238,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 2,
#    'TotalRecovered': 35,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Niue',
#    'CountryCode': 'NU',
#    'Slug': 'niue',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Norfolk Island',
#    'CountryCode': 'NF',
#    'Slug': 'norfolk-island',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Northern Mariana Islands',
#    'CountryCode': 'MP',
#    'Slug': 'northern-mariana-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 178,
#    'TotalConfirmed': 5865,
#    'NewDeaths': 5,
#    'TotalDeaths': 76,
#    'NewRecovered': 0,
#    'TotalRecovered': 32,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 33,
#    'TotalConfirmed': 331,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 61,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 609,
#    'TotalConfirmed': 3766,
#    'NewDeaths': 6,
#    'TotalDeaths': 53,
#    'NewRecovered': 48,
#    'TotalRecovered': 259,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 187,
#    'TotalConfirmed': 1988,
#    'NewDeaths': 8,
#    'TotalDeaths': 54,
#    'NewRecovered': 0,
#    'TotalRecovered': 13,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 2,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 9,
#    'TotalConfirmed': 113,
#    'NewDeaths': 2,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 12,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 280,
#    'TotalConfirmed': 2561,
#    'NewDeaths': 9,
#    'TotalDeaths': 92,
#    'NewRecovered': 8,
#    'TotalRecovered': 997,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 414,
#    'TotalConfirmed': 3660,
#    'NewDeaths': 11,
#    'TotalDeaths': 163,
#    'NewRecovered': 9,
#    'TotalRecovered': 73,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Pitcairn',
#    'CountryCode': 'PN',
#    'Slug': 'pitcairn',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 311,
#    'TotalConfirmed': 4413,
#    'NewDeaths': 13,
#    'TotalDeaths': 107,
#    'NewRecovered': 28,
#    'TotalRecovered': 162,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 452,
#    'TotalConfirmed': 11730,
#    'NewDeaths': 16,
#    'TotalDeaths': 311,
#    'NewRecovered': 65,
#    'TotalRecovered': 140,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Puerto Rico',
#    'CountryCode': 'PR',
#    'Slug': 'puerto-rico',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 228,
#    'TotalConfirmed': 1832,
#    'NewDeaths': 0,
#    'TotalDeaths': 4,
#    'NewRecovered': 8,
#    'TotalRecovered': 131,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 145,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 23,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 193,
#    'TotalConfirmed': 4057,
#    'NewDeaths': 25,
#    'TotalDeaths': 176,
#    'NewRecovered': 32,
#    'TotalRecovered': 406,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 954,
#    'TotalConfirmed': 6343,
#    'NewDeaths': 2,
#    'TotalDeaths': 47,
#    'NewRecovered': 51,
#    'TotalRecovered': 406,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 105,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Réunion',
#    'CountryCode': 'RE',
#    'Slug': 'réunion',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint Helena',
#    'CountryCode': 'SH',
#    'Slug': 'saint-helena',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint Pierre and Miquelon',
#    'CountryCode': 'PM',
#    'Slug': 'saint-pierre-and-miquelon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint-Barthélemy',
#    'CountryCode': 'BL',
#    'Slug': 'saint-barthélemy',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saint-Martin (French part)',
#    'CountryCode': 'MF',
#    'Slug': 'saint-martin-french-part',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 266,
#    'NewDeaths': 0,
#    'TotalDeaths': 32,
#    'NewRecovered': 0,
#    'TotalRecovered': 35,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 203,
#    'TotalConfirmed': 2605,
#    'NewDeaths': 4,
#    'TotalDeaths': 38,
#    'NewRecovered': 63,
#    'TotalRecovered': 551,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 226,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 10,
#    'TotalRecovered': 92,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 292,
#    'TotalConfirmed': 2200,
#    'NewDeaths': 7,
#    'TotalDeaths': 58,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 66,
#    'TotalConfirmed': 1375,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 24,
#    'TotalRecovered': 344,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 24,
#    'TotalConfirmed': 1021,
#    'NewDeaths': 2,
#    'TotalDeaths': 30,
#    'NewRecovered': 23,
#    'TotalRecovered': 102,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 1686,
#    'NewDeaths': 1,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 95,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'South Georgia and the South Sandwich Islands',
#    'CountryCode': 'GS',
#    'Slug': 'south-georgia-and-the-south-sandwich-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 5029,
#    'TotalConfirmed': 136675,
#    'NewDeaths': 700,
#    'TotalDeaths': 13341,
#    'NewRecovered': 2357,
#    'TotalRecovered': 40437,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 178,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 5,
#    'TotalRecovered': 38,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Svalbard and Jan Mayen Islands',
#    'CountryCode': 'SJ',
#    'Slug': 'svalbard-and-jan-mayen-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 4,
#    'TotalRecovered': 4,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 376,
#    'TotalConfirmed': 7206,
#    'NewDeaths': 76,
#    'TotalDeaths': 477,
#    'NewRecovered': 0,
#    'TotalRecovered': 205,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 557,
#    'TotalConfirmed': 21657,
#    'NewDeaths': 50,
#    'TotalDeaths': 765,
#    'NewRecovered': 1641,
#    'TotalRecovered': 8056,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 373,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 7,
#    'TotalRecovered': 57,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 51,
#    'TotalConfirmed': 2220,
#    'NewDeaths': 3,
#    'TotalDeaths': 26,
#    'NewRecovered': 0,
#    'TotalRecovered': 793,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 58,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 3,
#    'TotalRecovered': 23,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Tokelau',
#    'CountryCode': 'TK',
#    'Slug': 'tokelau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 105,
#    'NewDeaths': 1,
#    'TotalDeaths': 8,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 22,
#    'TotalConfirmed': 596,
#    'NewDeaths': 0,
#    'TotalDeaths': 22,
#    'NewRecovered': 0,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 3148,
#    'TotalConfirmed': 30217,
#    'NewDeaths': 75,
#    'TotalDeaths': 649,
#    'NewRecovered': 284,
#    'TotalRecovered': 1326,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Turkmenistan',
#    'CountryCode': 'TM',
#    'Slug': 'turkmenistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Turks and Caicos Islands',
#    'CountryCode': 'TC',
#    'Slug': 'turks-and-caicos-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Tuvalu',
#    'CountryCode': 'TV',
#    'Slug': 'tuvalu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'US Minor Outlying Islands',
#    'CountryCode': 'UM',
#    'Slug': 'us-minor-outlying-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 52,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 1319,
#    'NewDeaths': 1,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 28,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 277,
#    'TotalConfirmed': 2076,
#    'NewDeaths': 1,
#    'TotalDeaths': 11,
#    'NewRecovered': 23,
#    'TotalRecovered': 167,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 3843,
#    'TotalConfirmed': 52279,
#    'NewDeaths': 442,
#    'TotalDeaths': 5385,
#    'NewRecovered': 58,
#    'TotalRecovered': 287,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 29542,
#    'TotalConfirmed': 366607,
#    'NewDeaths': 1164,
#    'TotalDeaths': 10783,
#    'NewRecovered': 2133,
#    'TotalRecovered': 19581,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 406,
#    'NewDeaths': 1,
#    'TotalDeaths': 6,
#    'NewRecovered': 11,
#    'TotalRecovered': 104,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 115,
#    'TotalConfirmed': 457,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 30,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 165,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 13,
#    'TotalRecovered': 65,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 245,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 5,
#    'TotalRecovered': 95,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Virgin Islands, US',
#    'CountryCode': 'VI',
#    'Slug': 'virgin-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Wallis and Futuna Islands',
#    'CountryCode': 'WF',
#    'Slug': 'wallis-and-futuna-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 2,
#    'TotalRecovered': 5,
#    'Date': '2020-04-07T07:03:30Z'},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-04-07T07:03:30Z'}],
#  'Date': '2020-04-07T07:03:30Z'}

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
