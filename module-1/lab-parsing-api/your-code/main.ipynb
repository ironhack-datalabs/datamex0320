# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code himport json
import requests as req
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = "https://coinpaprika1.p.rapidapi.com/tickers"

headers = {
    'x-rapidapi-host': "coinpaprika1.p.rapidapi.com",
    'x-rapidapi-key': "222fe66062msh18b422a8dc0c4dbp1cff30jsn366a602cfff9"
    }

response = req.request("GET", url, headers=headers)

print(response.text)
# Out:
# [{"id":"btc-bitcoin","name":"Bitcoin","symbol":"BTC","rank":1,"circulating_supply":18309262,"total_supply":18309238,"max_supply":21000000,"beta_value":1.03285,"last_updated":"2020-04-07T00:56:41Z","quotes":{"USD":{"price":7391.96952876,"volume_24h":35682355389.539,"volume_24h_change_24h":58.77,"market_cap":135341506798,"market_cap_change_24h":7.47,"percent_change_1h":1.3,"percent_change_12h":3.95,"percent_change_24h":7.46,"percent_change_7d":14.31,"percent_change_30d":-17.93,"percent_change_1y":40.46,"ath_price":20089,"ath_date":"2017-12-17T12:19:00Z","percent_from_price_ath":-63.2}}},{"id":"miota-iota","name":"IOTA","symbol":"MIOTA","rank":25,"circulating_supply":2779530283,"total_supply":2779530283,"max_supply":2779530283,"beta_value":0.989088,"last_updated":"2020-04-07T00:56:41Z","quotes":{"USD":{"price":0.16832315,"volume_24h":7085160.9672663,"volume_24h_change_24h":161.14,"market_cap":467859292,"market_cap_change_24h":11.5,"percent_change_1h":1.53,"percent_change_12h":4.18,"perc
# ...

# %%
results = response.json()
results
# Out:
# [{'beta_value': 1.03285,
#   'circulating_supply': 18309262,
#   'id': 'btc-bitcoin',
#   'last_updated': '2020-04-07T00:56:41Z',
#   'max_supply': 21000000,
#   'name': 'Bitcoin',
#   'quotes': {'USD': {'ath_date': '2017-12-17T12:19:00Z',
#     'ath_price': 20089,
#     'market_cap': 135341506798,
#     'market_cap_change_24h': 7.47,
#     'percent_change_12h': 3.95,
#     'percent_change_1h': 1.3,
#     'percent_change_1y': 40.46,
#     'percent_change_24h': 7.46,
#     'percent_change_30d': -17.93,
#     'percent_change_7d': 14.31,
#     'percent_from_price_ath': -63.2,
#     'price': 7391.96952876,
#     'volume_24h': 35682355389.539,
#     'volume_24h_change_24h': 58.77}},
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 18309238},
#  {'beta_value': 0.989088,
#   'circulating_supply': 2779530283,
#   'id': 'miota-iota',
#   'last_updated': '2020-04-07T00:56:41Z',
#   'max_supply': 2779530283,
#   'name': 'IOTA',
#   'quotes': {'USD': {'ath_date': '2017-12-19T20:09:00Z',
# ...

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
flat_json=json_normalize(response.json())

flat_json.head()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#              id      name symbol  rank  circulating_supply  total_supply  \
# 0   btc-bitcoin   Bitcoin    BTC     1            18309262      18309238
# 1    miota-iota      IOTA  MIOTA    25          2779530283    2779530283
# 2       eos-eos       EOS    EOS     8           921572162    1018272174
# 3  eth-ethereum  Ethereum    ETH     2           110412255     110412223
# 4       xrp-xrp       XRP    XRP     3         43978966311   99991020177
#
#      max_supply  beta_value          last_updated  quotes.USD.price  ...  \
# 0      21000000    1.032850  2020-04-07T00:56:41Z       7391.969529  ...
# 1    2779530283    0.989088  2020-04-07T00:56:41Z          0.168323  ...
# 2             0    1.090310  2020-04-07T00:56:41Z          2.788439  ...
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
data=flat_json

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 2410 non-null   object
#  1   name                               2410 non-null   object
#  2   symbol                             2410 non-null   object
#  3   rank                               2410 non-null   int64
#  4   circulating_supply                 2410 non-null   int64
#  5   total_supply                       2410 non-null   int64
#  6   max_supply                         2410 non-null   int64
#  7   beta_value                         2410 non-null   float64
#  8   last_updated                       2410 non-null   object
#  9   quotes.USD.price                   2410 non-null   float64
#  10  quotes.USD.volume_24h              2410 non-null   float64
# ...

# %%
data.columns = data.columns.to_series().apply(lambda x: x.strip())

# %%
data["rank"].value_counts()
# Out:
# 212     2
# 1256    2
# 1693    2
# 923     2
# 642     2
#        ..
# 2408    1
# 361     1
# 2410    1
# 363     1
# 2049    1
# Name: rank, Length: 2265, dtype: int64

# %%
data["rank"]=data["rank"].drop_duplicates()

# %%
data[(data["beta_value"]==1) | (data["quotes.USD.ath_price"]>1000)][['name', 'symbol']]#criptomonedas que empezaron valieorn 1 o mas en beta y ahora valen mas de 1000 usd
# Out:
#                           name symbol
# 0                      Bitcoin    BTC
# 3                     Ethereum    ETH
# 5                 Bitcoin Cash    BCH
# 11                        Dash   DASH
# 17                       Zcash    ZEC
# 34                       Obyte  GBYTE
# 134                 Unobtanium    UNO
# 176             EDC Blockchain    EDC
# 226                 Aurum Coin     AU
# 234                    42-coin     42
# 344                  Project-X  NANOX
# 398                   SegWit2x    B2X
# 399                      Mixin    XIN
# 405                  TerraNova    TER
# 412          Lightning Bitcoin   LBTC
# 466                      Maker    MKR
# 626                     Xaurum   XAUR
# 682           Primalbase Token    PBT
# 730            IDEX Membership   IDXM
# 734                       WETH   WETH
# 939                     Daneel    DAN
# 1126                      sUSD   SUSD
# 1258                 ThoreCoin    THR
# 1278                   Arbidex    ABX
# ...

# %%
data.circulating_supply.sum()#El total de criptomonedas que hay en circulacion
# Out:
# 19620263607828
