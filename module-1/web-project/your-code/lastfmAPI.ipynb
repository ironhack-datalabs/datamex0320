# %%
#lastfm api
import requests

# %%
url='http://ws.audioscrobbler.com/2.0/?method=artist.gettopalbums&artist=ladygaga&api_key=api_key&format=json&autocorrect[1]]'
resp=requests.get(url)

results=resp.json()

# %%
import pandas as pd

data=pd.DataFrame(results)

data.head()
#Obtención de datos de los álbumes de Lady Gaga
# Out:
#                                                topalbums
# @attr  {'artist': 'Lady Gaga', 'page': '1', 'perPage'...
# album  [{'name': 'The Fame', 'playcount': 48617484, '...

# %%
from pandas.io.json import json_normalize

flat_json=json_normalize(resp.json())
flat_json
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                      topalbums.album topalbums.@attr.artist  \
# 0  [{'name': 'The Fame', 'playcount': 48617484, '...              Lady Gaga
#
#   topalbums.@attr.page topalbums.@attr.perPage topalbums.@attr.totalPages  \
# 0                    1                      50                       2631
#
#   topalbums.@attr.total
# 0                131544

# %%
flat_json['topalbums.album'][0] #Exploración del archivo .json
# Out:
# [{'name': 'The Fame',
#   'playcount': 48617484,
#   'mbid': 'd1bcf9e5-a5e4-3f99-908c-610b2d0e33ed',
#   'url': 'https://www.last.fm/music/Lady+Gaga/The+Fame',
#   'artist': {'name': 'Lady Gaga',
#    'mbid': '650e7db6-b795-4eb5-a702-5ea2fc46c848',
#    'url': 'https://www.last.fm/music/Lady+Gaga'},
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/77a7fb267f689750ad32fd52d2dc4a71.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/77a7fb267f689750ad32fd52d2dc4a71.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/77a7fb267f689750ad32fd52d2dc4a71.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/77a7fb267f689750ad32fd52d2dc4a71.png',
#     'size': 'extralarge'}]},
#  {'name': 'The Fame Monster',
#   'playcount': 38256253,
#   'mbid': 'cbc79f64-fdb9-3ce3-ae32-c9d18c19584f',
#   'url': 'https://www.last.fm/music/Lady+Gaga/The+Fame+Monster',
# ...

# %%
data2=pd.DataFrame(flat_json['topalbums.album'][0])
data2
# Out:
#                                                  name  playcount  \
# 0                                            The Fame   48617484
# 1                                    The Fame Monster   38256253
# 2                                       Born This Way   39114441
# 3                                              ARTPOP   30794636
# 4                                          Just Dance     953510
# 5                                     JOANNE (Deluxe)   11020691
# 6                                         Bad Romance    1410119
# 7                           a star is born soundtrack    6189209
# 8             The Fame Monster (International Deluxe)    3291999
# 9                                            Applause    1512103
# 10  Born This Way (International Special Edition V...    5577172
# 11                  The Fame Monster (Deluxe Edition)    5738567
# 12       A Star Is Born Soundtrack (Without Dialogue)    4813636
# ...

# %%
flat_json2=json_normalize(flat_json['topalbums.album'][0])
flat_json2 #Obtención de la información requerida
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                                  name  playcount  \
# 0                                            The Fame   48617484
# 1                                    The Fame Monster   38256253
# 2                                       Born This Way   39114441
# 3                                              ARTPOP   30794636
# 4                                          Just Dance     953510
# 5                                     JOANNE (Deluxe)   11020691
# 6                                         Bad Romance    1410119
# 7                           a star is born soundtrack    6189209
# 8             The Fame Monster (International Deluxe)    3291999
# 9                                            Applause    1512103
# ...

# %%
flat_json2.to_csv('lastfmapi.csv')
