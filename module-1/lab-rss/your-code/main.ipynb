# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
#!pip3 install feedparser
import feedparser as fp

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
oreilly= fp.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
oreilly.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
oreilly.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print(oreilly.feed.title)
print(oreilly.feed.subtitle)
#print(oreilly.feed.author) no hay de autor ya...
print(oreilly.feed.link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(oreilly.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
oreilly.entries[0].keys() #de entries, sacamos keys, igual que al principio
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
#mejor a variable, a la migue
titles = [oreilly.entries[i].title for i in range(len(oreilly.entries))]
titles
# Out:
# ['Four short links: 9 April 2020',
#  'Four short links: 8 April 2020',
#  'Four short links: 7 April 2020',
#  'Governance and Discovery',
#  'Four short links: 6 April 2020',
#  'Four short links: 3 April 2020',
#  'Four short links: 2 April 2020',
#  'Four short links: 1 April 2020',
#  'Four short links: 31 March 2020',
#  'What you need to know about product management for AI',
#  'The unreasonable importance of data preparation',
#  'Four short links: 24 March 2020',
#  '3 ways to confront modern business challenges',
#  'An enterprise vision is your company’s North Star',
#  'Leaders need to mobilize change-ready workforces',
#  'Great leaders inspire innovation and creativity from within their workforces',
#  'Strong leaders forge an intersection of knowledge and experience',
#  'Four short links: 23 March 2020',
#  'Four short links: 20 March 2020',
#  '6 trends framing the state of AI and ML',
#  'Four short links: 19 March 2020',
# ...

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
x= len([i for i in titles if 'Four short links' in i])/len(oreilly.entries)
print(x*100 )
# Out:
# 61.66666666666667

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
entradas = pd.DataFrame(oreilly.entries)
entradas
# Out:
#                                                 title  \
# 0                      Four short links: 9 April 2020
# 1                      Four short links: 8 April 2020
# 2                      Four short links: 7 April 2020
# 3                            Governance and Discovery
# 4                      Four short links: 6 April 2020
# 5                      Four short links: 3 April 2020
# 6                      Four short links: 2 April 2020
# 7                      Four short links: 1 April 2020
# 8                     Four short links: 31 March 2020
# 9   What you need to know about product management...
# 10    The unreasonable importance of data preparation
# 11                    Four short links: 24 March 2020
# 12      3 ways to confront modern business challenges
# 13  An enterprise vision is your company’s North Star
# 14   Leaders need to mobilize change-ready workforces
# 15  Great leaders inspire innovation and creativit...
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
#no me jala porque en punto 4 no pude extraer el autor, pero por lo visto iría algo así..

authors = entries.groupby(['author'], as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-418c93cb23f8> in <module>
# ----> 1 authors = entradas.groupby(['autor'], as_index=False).agg({'titulo':'count'})
#       2 #authors.columns = ['autor', 'entradas']
#       3 authors.sort_values('entradas', ascending=False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ...

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
entries['title_length'] = entries['title'].apply(len)
entries[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-da328b76a3e1> in <module>
# ----> 1 entries['title_length'] = entries['title'].apply(len)
#       2 entries[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
#
# NameError: name 'entries' is not defined

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
list(entries[entries['summary'].str.contains('machine learning')]['title'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-30e0979d2a40> in <module>
# ----> 1 list(entries[entries['summary'].str.contains('machine learning')]['title'])
#
# NameError: name 'entries' is not defined
