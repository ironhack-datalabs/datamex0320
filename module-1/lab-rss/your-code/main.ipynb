# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser
import pandas as pd

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
reddit = feedparser.parse(url)
print(reddit['feed'])
# Out:
# {'title': 'Radar', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://feeds.feedburner.com/oreilly/radar/atom', 'value': 'Radar'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.oreilly.com/radar'}, {'rel': 'self', 'type': 'application/rss+xml', 'href': 'http://feeds.feedburner.com/oreilly/radar/atom'}, {'rel': 'hub', 'href': 'http://pubsubhubbub.appspot.com/', 'type': 'text/html'}], 'link': 'https://www.oreilly.com/radar', 'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology', 'subtitle_detail': {'type': 'text/html', 'language': None, 'base': 'http://feeds.feedburner.com/oreilly/radar/atom', 'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'}, 'updated': 'Wed, 08 Apr 2020 11:48:28 +0000', 'updated_parsed': time.struct_time(tm_year=2020, tm_mon=4, tm_mday=8, tm_hour=11, tm_min=48, tm_sec=28, tm_wday=2, tm_yday=99, tm_isdst=0), 'language': 'en-US', 'sy_updateperiod': 'hourly', 'sy_updatefrequency': '1', 'generator_detail': {'name': 'https://wordpress.org/?v=5.3.2'}, 'generator': 'https://wordpress.org/?v=5.3.2', 'feedburner_info': {'uri': 'oreilly/radar/atom'}, 'geo_lat': '38.393314', 'geo_long': '-122.836667', 'feedburner_emailserviceid': 'oreilly/radar/atom', 'feedburner_feedburnerhostname': 'https://feedburner.google.com'}

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
reddit.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
reddit.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print (reddit.feed.title)
print (reddit.feed.subtitle)
print (reddit.feed.link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(reddit.entries[0])
# Out:
# 19

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
reddit.entries[0]
# Out:
# {'title': 'Four short links: 8 April 2020',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#   'value': 'Four short links: 8 April 2020'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V8u8aZ2VPaE/'}],
#  'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V8u8aZ2VPaE/',
#  'comments': 'https://www.oreilly.com/radar/four-short-links-8-april-2020/#respond',
#  'published': 'Wed, 08 Apr 2020 11:48:28 +0000',
#  'published_parsed': time.struct_time(tm_year=2020, tm_mon=4, tm_mday=8, tm_hour=11, tm_min=48, tm_sec=28, tm_wday=2, tm_yday=99, tm_isdst=0),
#  'authors': [{'name': 'Nat Torkington'}],
#  'author': 'Nat Torkington',
#  'author_detail': {'name': 'Nat Torkington'},
#  'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#   {'term': 'Signals', 'scheme': None, 'label': None}],
#  'id': 'https://www.oreilly.com/radar/?p=12611',
#  'guidislink': False,
#  'summary': 'System Design for Advanced Beginners &#8212; a friendly explanation of the what and why of systems, with acknowledgement of the real world like There are many tools out there, each with different strengths and weaknesses, and many ways to build a technology company. The real, honest reasons that we will make many of our technological [&#8230;]',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#   'value': 'System Design for Advanced Beginners &#8212; a friendly explanation of the what and why of systems, with acknowledgement of the real world like There are many tools out there, each with different strengths and weaknesses, and many ways to build a technology company. The real, honest reasons that we will make many of our technological [&#8230;]'},
#  'content': [{'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': '<ol>\n<li><a href="https://robertheaton.com/2020/04/06/systems-design-for-advanced-beginners/">System Design for Advanced Beginners</a> &#8212; a friendly explanation of the what and why of systems, with acknowledgement of the real world like <i>There are many tools out there, each with different strengths and weaknesses, and many ways to build a technology company. The real, honest reasons that we will make many of our technological choices will be “we chose X because Sara knows a lot about X” and “we chose Y on the spur of the moment when it didn’t seem like a big decision and we never found the time to re-evaluate.”</i></li>\n<li><a href="https://meet.primrosevr.com/">Lozya</a> &#8212; <i>Teleconferencing with an RPG map. Walk around, talk to folks, have private conversations by huddling in a corner, or drop in on other conversations. Ideal for meetups!</i></li>\n<li><a href="https://www.hammerspoon.org/">Hammerspoon</a> &#8212; <i>desktop automation framework for macOS. It lets you write Lua scripts that hook into operating system functionality, allowing you to interact with the keyboard/mouse, windows, displays, filesystem, and much more.</i> (via <a href="https://missing.csail.mit.edu/2020/potpourri/">CSAIL&#8217;s Missing Semester Potpourri</a>)</li>\n<li><a href="https://github.com/blanchette/logical_verification_2020/raw/master/hitchhikers_guide.pdf">The Hitchiker&#8217;s Guide to Logical Verification</a> (PDF) &#8212; book for <a href="https://lean-forward.github.io/logical-verification/2020/">a course</a>, using Microsoft Research&#8217;s <a href="https://leanprover.github.io/">Lean</a> theorem prover.</li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/V8u8aZ2VPaE" height="1" width="1" alt=""/>'}],
#  'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-8-april-2020/feed/',
#  'slash_comments': '0',
#  'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-8-april-2020/'}

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [reddit.entries[i].title for i in range(len(reddit.entries))]
print(titles)
# Out:
# ['Four short links: 8 April 2020', 'Four short links: 7 April 2020', 'Governance and Discovery', 'Four short links: 6 April 2020', 'Four short links: 3 April 2020', 'Four short links: 2 April 2020', 'Four short links: 1 April 2020', 'Four short links: 31 March 2020', 'What you need to know about product management for AI', 'The unreasonable importance of data preparation', 'Four short links: 24 March 2020', '3 ways to confront modern business challenges', 'An enterprise vision is your company’s North Star', 'Leaders need to mobilize change-ready workforces', 'Great leaders inspire innovation and creativity from within their workforces', 'Strong leaders forge an intersection of knowledge and experience', 'Four short links: 23 March 2020', 'Four short links: 20 March 2020', '6 trends framing the state of AI and ML', 'Four short links: 19 March 2020', 'It’s an unprecedented crisis: 8 things to do right now', 'AI adoption in the enterprise 2020', 'Four short links: 18 March 2020', 'Four short links: 17 March 2020', 'Four short links: 16 March 2020', 'Four short links: 13 March 2020', 'Four short links: 12 March 2020', 'Four short links: 11 March 2020', 'Four short links: 10 March 2020', 'Four short links: 9 March 2020', 'Four short links: 6 March 2020', 'Radar trends to watch: March 2020', 'Four short links: 5 March 2020', 'Remembering Freeman Dyson', 'Four short links: 4 March 2020', 'Four short links: 3 March 2020', 'The death of Agile?', 'Four short links: 2 March 2020', 'Four short links: 28 February 2020', 'Four short links: 27 February 2020', 'Highlights from the O’Reilly Software Architecture Conference in New York 2020', 'Intellectual control', 'Architecture.Next: Invalidating old axioms', 'Where do great architectures come from?', 'Four short links: 26 February 2020', 'Sometimes I draw', 'From the trenches: Rachel Laycock', 'The elephant in the architecture', 'Four short links: 25 February 2020', 'Four short links: 24 February 2020', 'Four short links: 22 February 2020', 'Four short links: 20 February 2020', '10 ways to get untapped talent in your organization to contribute', 'Four short links: 19 February 2020', '5 key areas for tech leaders to watch in 2020', 'Four short links: 18 February 2020', 'Four short links: 17 February 2020', 'Four short links: 14 February 2020', 'Four short links: 13 February 2020', 'The state of data quality in 2020']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
c=0
for i in titles:
    if i.startswith("Four"):
        c+=1
total =len(titles)
percentage = (c*100/total)
percentage
# Out:
# 60.0

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
df = pd.DataFrame(reddit.entries)
df
# Out:
#                                                 title  \
# 0                      Four short links: 8 April 2020
# 1                      Four short links: 7 April 2020
# 2                            Governance and Discovery
# 3                      Four short links: 6 April 2020
# 4                      Four short links: 3 April 2020
# 5                      Four short links: 2 April 2020
# 6                      Four short links: 1 April 2020
# 7                     Four short links: 31 March 2020
# 8   What you need to know about product management...
# 9     The unreasonable importance of data preparation
# 10                    Four short links: 24 March 2020
# 11      3 ways to confront modern business challenges
# 12  An enterprise vision is your company’s North Star
# 13   Leaders need to mobilize change-ready workforces
# 14  Great leaders inspire innovation and creativit...
# 15  Strong leaders forge an intersection of knowle...
# 16                    Four short links: 23 March 2020
# 17                    Four short links: 20 March 2020
# 18            6 trends framing the state of AI and ML
# 19                    Four short links: 19 March 2020
# 20  It’s an unprecedented crisis: 8 things to do r...
# 21                 AI adoption in the enterprise 2020
# 22                    Four short links: 18 March 2020
# 23                    Four short links: 17 March 2020
# 24                    Four short links: 16 March 2020
# 25                    Four short links: 13 March 2020
# 26                    Four short links: 12 March 2020
# 27                    Four short links: 11 March 2020
# 28                    Four short links: 10 March 2020
# 29                     Four short links: 9 March 2020
# 30                     Four short links: 6 March 2020
# 31                  Radar trends to watch: March 2020
# 32                     Four short links: 5 March 2020
# 33                          Remembering Freeman Dyson
# 34                     Four short links: 4 March 2020
# 35                     Four short links: 3 March 2020
# 36                                The death of Agile?
# 37                     Four short links: 2 March 2020
# 38                 Four short links: 28 February 2020
# 39                 Four short links: 27 February 2020
# 40  Highlights from the O’Reilly Software Architec...
# 41                               Intellectual control
# 42         Architecture.Next: Invalidating old axioms
# 43            Where do great architectures come from?
# 44                 Four short links: 26 February 2020
# 45                                   Sometimes I draw
# 46                  From the trenches: Rachel Laycock
# 47                   The elephant in the architecture
# 48                 Four short links: 25 February 2020
# 49                 Four short links: 24 February 2020
# 50                 Four short links: 22 February 2020
# 51                 Four short links: 20 February 2020
# 52  10 ways to get untapped talent in your organiz...
# 53                 Four short links: 19 February 2020
# 54      5 key areas for tech leaders to watch in 2020
# 55                 Four short links: 18 February 2020
# 56                 Four short links: 17 February 2020
# 57                 Four short links: 14 February 2020
# 58                 Four short links: 13 February 2020
# 59                  The state of data quality in 2020
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
# 18  {'type': 'text/plain', 'language': None, 'base...
# 19  {'type': 'text/plain', 'language': None, 'base...
# 20  {'type': 'text/plain', 'language': None, 'base...
# 21  {'type': 'text/plain', 'language': None, 'base...
# 22  {'type': 'text/plain', 'language': None, 'base...
# 23  {'type': 'text/plain', 'language': None, 'base...
# 24  {'type': 'text/plain', 'language': None, 'base...
# 25  {'type': 'text/plain', 'language': None, 'base...
# 26  {'type': 'text/plain', 'language': None, 'base...
# 27  {'type': 'text/plain', 'language': None, 'base...
# 28  {'type': 'text/plain', 'language': None, 'base...
# 29  {'type': 'text/plain', 'language': None, 'base...
# 30  {'type': 'text/plain', 'language': None, 'base...
# 31  {'type': 'text/plain', 'language': None, 'base...
# 32  {'type': 'text/plain', 'language': None, 'base...
# 33  {'type': 'text/plain', 'language': None, 'base...
# 34  {'type': 'text/plain', 'language': None, 'base...
# 35  {'type': 'text/plain', 'language': None, 'base...
# 36  {'type': 'text/plain', 'language': None, 'base...
# 37  {'type': 'text/plain', 'language': None, 'base...
# 38  {'type': 'text/plain', 'language': None, 'base...
# 39  {'type': 'text/plain', 'language': None, 'base...
# 40  {'type': 'text/plain', 'language': None, 'base...
# 41  {'type': 'text/plain', 'language': None, 'base...
# 42  {'type': 'text/plain', 'language': None, 'base...
# 43  {'type': 'text/plain', 'language': None, 'base...
# 44  {'type': 'text/plain', 'language': None, 'base...
# 45  {'type': 'text/plain', 'language': None, 'base...
# 46  {'type': 'text/plain', 'language': None, 'base...
# 47  {'type': 'text/plain', 'language': None, 'base...
# 48  {'type': 'text/plain', 'language': None, 'base...
# 49  {'type': 'text/plain', 'language': None, 'base...
# 50  {'type': 'text/plain', 'language': None, 'base...
# 51  {'type': 'text/plain', 'language': None, 'base...
# 52  {'type': 'text/plain', 'language': None, 'base...
# 53  {'type': 'text/plain', 'language': None, 'base...
# 54  {'type': 'text/plain', 'language': None, 'base...
# 55  {'type': 'text/plain', 'language': None, 'base...
# 56  {'type': 'text/plain', 'language': None, 'base...
# 57  {'type': 'text/plain', 'language': None, 'base...
# 58  {'type': 'text/plain', 'language': None, 'base...
# 59  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 15  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 17  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 18  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 19  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 20  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 21  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 22  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 23  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 24  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 25  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 26  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 27  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 28  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 29  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 30  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 31  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 32  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 33  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 34  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 35  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 36  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 37  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 38  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 39  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 40  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 41  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 42  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 43  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 44  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 45  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 46  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 47  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 48  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 49  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 50  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 51  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 52  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 53  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 54  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 55  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 56  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 57  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 58  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 59  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
# 47  Tue, 25 Feb 2020 20:00:00 +0000   (2020, 2, 25, 20, 0, 0, 1, 56, 0)
# 48  Tue, 25 Feb 2020 05:01:00 +0000    (2020, 2, 25, 5, 1, 0, 1, 56, 0)
# 49  Mon, 24 Feb 2020 05:01:00 +0000    (2020, 2, 24, 5, 1, 0, 0, 55, 0)
# 50  Fri, 21 Feb 2020 05:01:00 +0000    (2020, 2, 21, 5, 1, 0, 4, 52, 0)
# 51  Thu, 20 Feb 2020 05:01:00 +0000    (2020, 2, 20, 5, 1, 0, 3, 51, 0)
# 52  Wed, 19 Feb 2020 11:00:00 +0000   (2020, 2, 19, 11, 0, 0, 2, 50, 0)
# 53  Wed, 19 Feb 2020 05:01:00 +0000    (2020, 2, 19, 5, 1, 0, 2, 50, 0)
# 54  Tue, 18 Feb 2020 11:00:00 +0000   (2020, 2, 18, 11, 0, 0, 1, 49, 0)
# 55  Tue, 18 Feb 2020 05:01:00 +0000    (2020, 2, 18, 5, 1, 0, 1, 49, 0)
# 56  Mon, 17 Feb 2020 05:01:00 +0000    (2020, 2, 17, 5, 1, 0, 0, 48, 0)
# 57  Fri, 14 Feb 2020 05:01:00 +0000    (2020, 2, 14, 5, 1, 0, 4, 45, 0)
# 58  Thu, 13 Feb 2020 05:01:00 +0000    (2020, 2, 13, 5, 1, 0, 3, 44, 0)
# 59  Wed, 12 Feb 2020 06:00:00 +0000    (2020, 2, 12, 6, 0, 0, 2, 43, 0)
#
#                                             authors  \
# 0                      [{'name': 'Nat Torkington'}]
# 1                      [{'name': 'Nat Torkington'}]
# 2                       [{'name': 'Mike Loukides'}]
# 3                      [{'name': 'Nat Torkington'}]
# 4                      [{'name': 'Nat Torkington'}]
# 5                      [{'name': 'Nat Torkington'}]
# 6                      [{'name': 'Nat Torkington'}]
# 7                      [{'name': 'Nat Torkington'}]
# 8   [{'name': 'Peter Skomoroch and Mike Loukides'}]
# 9                 [{'name': 'Hugo Bowne-Anderson'}]
# 10                     [{'name': 'Nat Torkington'}]
# 11                       [{'name': 'Rita J. King'}]
# 12                          [{'name': 'Jenn Webb'}]
# 13                          [{'name': 'Jenn Webb'}]
# 14                          [{'name': 'Jenn Webb'}]
# 15                          [{'name': 'Jenn Webb'}]
# 16                     [{'name': 'Nat Torkington'}]
# 17                     [{'name': 'Nat Torkington'}]
# 18    [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 19                     [{'name': 'Nat Torkington'}]
# 20                      [{'name': 'Cynthia Owens'}]
# 21    [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 22                     [{'name': 'Nat Torkington'}]
# 23                     [{'name': 'Nat Torkington'}]
# 24                     [{'name': 'Nat Torkington'}]
# 25                     [{'name': 'Nat Torkington'}]
# 26                     [{'name': 'Nat Torkington'}]
# 27                     [{'name': 'Nat Torkington'}]
# 28                     [{'name': 'Nat Torkington'}]
# 29                     [{'name': 'Nat Torkington'}]
# 30                     [{'name': 'Nat Torkington'}]
# 31                      [{'name': 'Mike Loukides'}]
# 32                     [{'name': 'Nat Torkington'}]
# 33                       [{'name': 'Tim O’Reilly'}]
# 34                     [{'name': 'Nat Torkington'}]
# 35                     [{'name': 'Nat Torkington'}]
# 36                      [{'name': 'Mike Loukides'}]
# 37                     [{'name': 'Nat Torkington'}]
# 38                     [{'name': 'Nat Torkington'}]
# 39                     [{'name': 'Nat Torkington'}]
# 40                         [{'name': 'Mac Slocum'}]
# 41                   [{'name': 'George Fairbanks'}]
# 42                      [{'name': 'Mark Richards'}]
# 43                   [{'name': 'Mary Poppendieck'}]
# 44                     [{'name': 'Nat Torkington'}]
# 45                         [{'name': 'Kai Holnes'}]
# 46       [{'name': 'Rachel Laycock and Neal Ford'}]
# 47                      [{'name': 'Martin Fowler'}]
# 48                     [{'name': 'Nat Torkington'}]
# 49                     [{'name': 'Nat Torkington'}]
# 50                     [{'name': 'Nat Torkington'}]
# 51                     [{'name': 'Nat Torkington'}]
# 52                      [{'name': 'Pamela Rucker'}]
# 53                     [{'name': 'Nat Torkington'}]
# 54    [{'name': 'Roger Magoulas and Steve Swoyer'}]
# 55                     [{'name': 'Nat Torkington'}]
# 56                     [{'name': 'Nat Torkington'}]
# 57                     [{'name': 'Nat Torkington'}]
# 58                     [{'name': 'Nat Torkington'}]
# 59    [{'name': 'Roger Magoulas and Steve Swoyer'}]
#
#                                author  \
# 0                      Nat Torkington
# 1                      Nat Torkington
# 2                       Mike Loukides
# 3                      Nat Torkington
# 4                      Nat Torkington
# 5                      Nat Torkington
# 6                      Nat Torkington
# 7                      Nat Torkington
# 8   Peter Skomoroch and Mike Loukides
# 9                 Hugo Bowne-Anderson
# 10                     Nat Torkington
# 11                       Rita J. King
# 12                          Jenn Webb
# 13                          Jenn Webb
# 14                          Jenn Webb
# 15                          Jenn Webb
# 16                     Nat Torkington
# 17                     Nat Torkington
# 18    Roger Magoulas and Steve Swoyer
# 19                     Nat Torkington
# 20                      Cynthia Owens
# 21    Roger Magoulas and Steve Swoyer
# 22                     Nat Torkington
# 23                     Nat Torkington
# 24                     Nat Torkington
# 25                     Nat Torkington
# 26                     Nat Torkington
# 27                     Nat Torkington
# 28                     Nat Torkington
# 29                     Nat Torkington
# 30                     Nat Torkington
# 31                      Mike Loukides
# 32                     Nat Torkington
# 33                       Tim O’Reilly
# 34                     Nat Torkington
# 35                     Nat Torkington
# 36                      Mike Loukides
# 37                     Nat Torkington
# 38                     Nat Torkington
# 39                     Nat Torkington
# 40                         Mac Slocum
# 41                   George Fairbanks
# 42                      Mark Richards
# 43                   Mary Poppendieck
# 44                     Nat Torkington
# 45                         Kai Holnes
# 46       Rachel Laycock and Neal Ford
# 47                      Martin Fowler
# 48                     Nat Torkington
# 49                     Nat Torkington
# 50                     Nat Torkington
# 51                     Nat Torkington
# 52                      Pamela Rucker
# 53                     Nat Torkington
# 54    Roger Magoulas and Steve Swoyer
# 55                     Nat Torkington
# 56                     Nat Torkington
# 57                     Nat Torkington
# 58                     Nat Torkington
# 59    Roger Magoulas and Steve Swoyer
#
#                                     author_detail  \
# 0                      {'name': 'Nat Torkington'}
# 1                      {'name': 'Nat Torkington'}
# 2                       {'name': 'Mike Loukides'}
# 3                      {'name': 'Nat Torkington'}
# 4                      {'name': 'Nat Torkington'}
# 5                      {'name': 'Nat Torkington'}
# 6                      {'name': 'Nat Torkington'}
# 7                      {'name': 'Nat Torkington'}
# 8   {'name': 'Peter Skomoroch and Mike Loukides'}
# 9                 {'name': 'Hugo Bowne-Anderson'}
# 10                     {'name': 'Nat Torkington'}
# 11                       {'name': 'Rita J. King'}
# 12                          {'name': 'Jenn Webb'}
# 13                          {'name': 'Jenn Webb'}
# 14                          {'name': 'Jenn Webb'}
# 15                          {'name': 'Jenn Webb'}
# 16                     {'name': 'Nat Torkington'}
# 17                     {'name': 'Nat Torkington'}
# 18    {'name': 'Roger Magoulas and Steve Swoyer'}
# 19                     {'name': 'Nat Torkington'}
# 20                      {'name': 'Cynthia Owens'}
# 21    {'name': 'Roger Magoulas and Steve Swoyer'}
# 22                     {'name': 'Nat Torkington'}
# 23                     {'name': 'Nat Torkington'}
# 24                     {'name': 'Nat Torkington'}
# 25                     {'name': 'Nat Torkington'}
# 26                     {'name': 'Nat Torkington'}
# 27                     {'name': 'Nat Torkington'}
# 28                     {'name': 'Nat Torkington'}
# 29                     {'name': 'Nat Torkington'}
# 30                     {'name': 'Nat Torkington'}
# 31                      {'name': 'Mike Loukides'}
# 32                     {'name': 'Nat Torkington'}
# 33                       {'name': 'Tim O’Reilly'}
# 34                     {'name': 'Nat Torkington'}
# 35                     {'name': 'Nat Torkington'}
# 36                      {'name': 'Mike Loukides'}
# 37                     {'name': 'Nat Torkington'}
# 38                     {'name': 'Nat Torkington'}
# 39                     {'name': 'Nat Torkington'}
# 40                         {'name': 'Mac Slocum'}
# 41                   {'name': 'George Fairbanks'}
# 42                      {'name': 'Mark Richards'}
# 43                   {'name': 'Mary Poppendieck'}
# 44                     {'name': 'Nat Torkington'}
# 45                         {'name': 'Kai Holnes'}
# 46       {'name': 'Rachel Laycock and Neal Ford'}
# 47                      {'name': 'Martin Fowler'}
# 48                     {'name': 'Nat Torkington'}
# 49                     {'name': 'Nat Torkington'}
# 50                     {'name': 'Nat Torkington'}
# 51                     {'name': 'Nat Torkington'}
# 52                      {'name': 'Pamela Rucker'}
# 53                     {'name': 'Nat Torkington'}
# 54    {'name': 'Roger Magoulas and Steve Swoyer'}
# 55                     {'name': 'Nat Torkington'}
# 56                     {'name': 'Nat Torkington'}
# 57                     {'name': 'Nat Torkington'}
# 58                     {'name': 'Nat Torkington'}
# 59    {'name': 'Roger Magoulas and Steve Swoyer'}
#
#                                                  tags  \
# 0   [{'term': 'Four Short Links', 'scheme': None, ...
# 1   [{'term': 'Four Short Links', 'scheme': None, ...
# 2   [{'term': 'Radar Column', 'scheme': None, 'lab...
# 3   [{'term': 'Four Short Links', 'scheme': None, ...
# 4   [{'term': 'Four Short Links', 'scheme': None, ...
# 5   [{'term': 'Four Short Links', 'scheme': None, ...
# 6   [{'term': 'Four Short Links', 'scheme': None, ...
# 7   [{'term': 'Four Short Links', 'scheme': None, ...
# 8   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 10  [{'term': 'Four Short Links', 'scheme': None, ...
# 11  [{'term': 'Future of the Firm', 'scheme': None...
# 12  [{'term': 'Future of the Firm', 'scheme': None...
# 13  [{'term': 'Future of the Firm', 'scheme': None...
# 14  [{'term': 'Future of the Firm', 'scheme': None...
# 15  [{'term': 'Future of the Firm', 'scheme': None...
# 16  [{'term': 'Four Short Links', 'scheme': None, ...
# 17  [{'term': 'Four Short Links', 'scheme': None, ...
# 18  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 19  [{'term': 'Four Short Links', 'scheme': None, ...
# 20  [{'term': 'Future of the Firm', 'scheme': None...
# 21  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 22  [{'term': 'Four Short Links', 'scheme': None, ...
# 23  [{'term': 'Four Short Links', 'scheme': None, ...
# 24  [{'term': 'Four Short Links', 'scheme': None, ...
# 25  [{'term': 'Four Short Links', 'scheme': None, ...
# 26  [{'term': 'Four Short Links', 'scheme': None, ...
# 27  [{'term': 'Four Short Links', 'scheme': None, ...
# 28  [{'term': 'Four Short Links', 'scheme': None, ...
# 29  [{'term': 'Four Short Links', 'scheme': None, ...
# 30  [{'term': 'Four Short Links', 'scheme': None, ...
# 31  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 32  [{'term': 'Four Short Links', 'scheme': None, ...
# 33  [{'term': 'Innovation & Disruption', 'scheme':...
# 34  [{'term': 'Four Short Links', 'scheme': None, ...
# 35  [{'term': 'Four Short Links', 'scheme': None, ...
# 36  [{'term': 'Next Architecture', 'scheme': None,...
# 37  [{'term': 'Four Short Links', 'scheme': None, ...
# 38  [{'term': 'Four Short Links', 'scheme': None, ...
# 39  [{'term': 'Four Short Links', 'scheme': None, ...
# 40  [{'term': 'Next Architecture', 'scheme': None,...
# 41  [{'term': 'Next Architecture', 'scheme': None,...
# 42  [{'term': 'Next Architecture', 'scheme': None,...
# 43  [{'term': 'Next Architecture', 'scheme': None,...
# 44  [{'term': 'Four Short Links', 'scheme': None, ...
# 45  [{'term': 'Next Architecture', 'scheme': None,...
# 46  [{'term': 'Next Architecture', 'scheme': None,...
# 47  [{'term': 'Next Architecture', 'scheme': None,...
# 48  [{'term': 'Four Short Links', 'scheme': None, ...
# 49  [{'term': 'Four Short Links', 'scheme': None, ...
# 50  [{'term': 'Four Short Links', 'scheme': None, ...
# 51  [{'term': 'Four Short Links', 'scheme': None, ...
# 52  [{'term': 'Future of the Firm', 'scheme': None...
# 53  [{'term': 'Four Short Links', 'scheme': None, ...
# 54  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 55  [{'term': 'Four Short Links', 'scheme': None, ...
# 56  [{'term': 'Four Short Links', 'scheme': None, ...
# 57  [{'term': 'Four Short Links', 'scheme': None, ...
# 58  [{'term': 'Four Short Links', 'scheme': None, ...
# 59  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                         id  guidislink  \
# 0   https://www.oreilly.com/radar/?p=12611       False
# 1   https://www.oreilly.com/radar/?p=12606       False
# 2   https://www.oreilly.com/radar/?p=12594       False
# 3   https://www.oreilly.com/radar/?p=12590       False
# 4   https://www.oreilly.com/radar/?p=12585       False
# 5   https://www.oreilly.com/radar/?p=12577       False
# 4   The Zero Trust Learning Curve (Palo Alto Netwo...
# 5   Imperial College&#8217;s COVID19 Model &#8212;...
# 6   Replaying Traffic to Test Proprietary Systems ...
# 7   Medtronic Releases Ventilator Designs &#8212; ...
# 8   If you’re already a software product manager (...
# 9   In a world focused on buzzword-driven models a...
# 10  Potential Distributed Reading Group on Distrib...
# 11  I interviewed four business leaders in late 20...
# 12  Rita J. King, co-director and EVP for business...
# 13  Rita J. King, co-director and EVP for business...
# 14  Rita J. King, co-director and EVP for business...
# 15  Rita J. King, co-director and EVP for business...
# 16  Stanza: A Python Natural Language Processing T...
# 17  NASCAR Replaces Canceled Races with Esports Fe...
# 18  O’Reilly online learning is a trove of informa...
# 19  Dos and Don&#8217;ts in Open Source (Olaf Geir...
# 20  Even with a stellar crisis plan, the COVID-19 ...
# 21  Last year, when we felt interest in artificial...
# 22  Inklewriter &#8212; open source interactive te...
# 23  How the Great Firewall Discovers Hidden Circum...
# 24  The Uncensored Library &#8212; Reporters Witho...
# 25  OpenAM &#8212; an open-access management solut...
# 26  AWS Bill Analysis &#8212; always interesting t...
# 27  Pluralistic &#8212; Cory Doctorow&#8217;s news...
# 28  MLflow &#8212; an open source platform to mana...
# 29  Sno &#8212; Distributed version control for ge...
# 30  Soul of a New Machine: Rethinking the Computer...
# 31  AI in practice In his book TinyML, Pete Warden...
# 32  libfacedetection &#8212; they claim 1000fps. O...
# 33  Freeman Dyson died last week at the age of 96 ...
# 34  tota11y &#8212; an [open source] accessibility...
# 35  Facebook&#8217;s Incomplete Download Your Data...
# 36  I read an article on the death of Agile. It&#8...
# 37  Gandalf: An Intelligent, End-to-end Analytics ...
# 38  Mapping Coronavirus Responsibly (ESRI) &#8212;...
# 39  BellTopo Sans &#8212; typeface and free font i...
# 40  People from across the software architecture w...
# 41  This is a keynote highlight from the O&#8217;R...
# 42  This is a keynote highlight from the O&#8217;R...
# 43  This is a keynote highlight from the O&#8217;R...
# 44  kernel-wasm &#8212; Safely run WebAssembly in ...
# 45  This is a keynote highlight from the O&#8217;R...
# 46  This is a keynote highlight from the O&#8217;R...
# 47  This is a keynote highlight from the O&#8217;R...
# 48  Dispatch &#8212; Netflix&#8217;s incident mana...
# 49  YOLO Creator Leaves Computer Vision &#8212; Jo...
# 50  Teachable Machine &#8212; Google&#8217;s codel...
# 51  Hacker Laws &#8212; a lot of classics, like Cu...
# 52  Every day, leaders actively look for ways to u...
# 53  Devil&#8217;s Dictionary of Programming &#8212...
# 54  O’Reilly online learning contains information ...
# 55  Millions of Tiny Databases &#8212; a distribut...
# 56  Coders are not Hackers: Hacker Culture is Dead...
# 57  ABD &#8212; Course materials for Advanced Bina...
# 58  Ofcom To Regulate UK Internet &#8212; The regu...
# 59  We suspected that data quality was a topic bri...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
# 18  {'type': 'text/html', 'language': None, 'base'...
# 19  {'type': 'text/html', 'language': None, 'base'...
# 20  {'type': 'text/html', 'language': None, 'base'...
# 21  {'type': 'text/html', 'language': None, 'base'...
# 22  {'type': 'text/html', 'language': None, 'base'...
# 23  {'type': 'text/html', 'language': None, 'base'...
# 24  {'type': 'text/html', 'language': None, 'base'...
# 25  {'type': 'text/html', 'language': None, 'base'...
# 26  {'type': 'text/html', 'language': None, 'base'...
# 27  {'type': 'text/html', 'language': None, 'base'...
# 28  {'type': 'text/html', 'language': None, 'base'...
# 29  {'type': 'text/html', 'language': None, 'base'...
# 30  {'type': 'text/html', 'language': None, 'base'...
# 31  {'type': 'text/html', 'language': None, 'base'...
# 32  {'type': 'text/html', 'language': None, 'base'...
# 33  {'type': 'text/html', 'language': None, 'base'...
# 34  {'type': 'text/html', 'language': None, 'base'...
# 35  {'type': 'text/html', 'language': None, 'base'...
# 36  {'type': 'text/html', 'language': None, 'base'...
# 37  {'type': 'text/html', 'language': None, 'base'...
# 38  {'type': 'text/html', 'language': None, 'base'...
# 39  {'type': 'text/html', 'language': None, 'base'...
# 40  {'type': 'text/html', 'language': None, 'base'...
# 41  {'type': 'text/html', 'language': None, 'base'...
# 42  {'type': 'text/html', 'language': None, 'base'...
# 43  {'type': 'text/html', 'language': None, 'base'...
# 44  {'type': 'text/html', 'language': None, 'base'...
# 45  {'type': 'text/html', 'language': None, 'base'...
# 46  {'type': 'text/html', 'language': None, 'base'...
# 47  {'type': 'text/html', 'language': None, 'base'...
# 48  {'type': 'text/html', 'language': None, 'base'...
# 49  {'type': 'text/html', 'language': None, 'base'...
# 50  {'type': 'text/html', 'language': None, 'base'...
# 51  {'type': 'text/html', 'language': None, 'base'...
# 52  {'type': 'text/html', 'language': None, 'base'...
# 53  {'type': 'text/html', 'language': None, 'base'...
# 54  {'type': 'text/html', 'language': None, 'base'...
# 55  {'type': 'text/html', 'language': None, 'base'...
# 56  {'type': 'text/html', 'language': None, 'base'...
# 57  {'type': 'text/html', 'language': None, 'base'...
# 58  {'type': 'text/html', 'language': None, 'base'...
# 59  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
# 18  [{'type': 'text/html', 'language': None, 'base...
# 19  [{'type': 'text/html', 'language': None, 'base...
# 20  [{'type': 'text/html', 'language': None, 'base...
# 21  [{'type': 'text/html', 'language': None, 'base...
# 22  [{'type': 'text/html', 'language': None, 'base...
# 23  [{'type': 'text/html', 'language': None, 'base...
# 24  [{'type': 'text/html', 'language': None, 'base...
# 25  [{'type': 'text/html', 'language': None, 'base...
# 26  [{'type': 'text/html', 'language': None, 'base...
# 27  [{'type': 'text/html', 'language': None, 'base...
# 28  [{'type': 'text/html', 'language': None, 'base...
# 29  [{'type': 'text/html', 'language': None, 'base...
# 30  [{'type': 'text/html', 'language': None, 'base...
# 31  [{'type': 'text/html', 'language': None, 'base...
# 32  [{'type': 'text/html', 'language': None, 'base...
# 33  [{'type': 'text/html', 'language': None, 'base...
# 34  [{'type': 'text/html', 'language': None, 'base...
# 35  [{'type': 'text/html', 'language': None, 'base...
# 36  [{'type': 'text/html', 'language': None, 'base...
# 37  [{'type': 'text/html', 'language': None, 'base...
# 38  [{'type': 'text/html', 'language': None, 'base...
# 39  [{'type': 'text/html', 'language': None, 'base...
# 40  [{'type': 'text/html', 'language': None, 'base...
# 41  [{'type': 'text/html', 'language': None, 'base...
# 42  [{'type': 'text/html', 'language': None, 'base...
# 43  [{'type': 'text/html', 'language': None, 'base...
# 44  [{'type': 'text/html', 'language': None, 'base...
# 45  [{'type': 'text/html', 'language': None, 'base...
# 46  [{'type': 'text/html', 'language': None, 'base...
# 47  [{'type': 'text/html', 'language': None, 'base...
# 48  [{'type': 'text/html', 'language': None, 'base...
# 49  [{'type': 'text/html', 'language': None, 'base...
# 50  [{'type': 'text/html', 'language': None, 'base...
# 51  [{'type': 'text/html', 'language': None, 'base...
# 52  [{'type': 'text/html', 'language': None, 'base...
# 53  [{'type': 'text/html', 'language': None, 'base...
# 54  [{'type': 'text/html', 'language': None, 'base...
# 55  [{'type': 'text/html', 'language': None, 'base...
# 56  [{'type': 'text/html', 'language': None, 'base...
# 57  [{'type': 'text/html', 'language': None, 'base...
# 58  [{'type': 'text/html', 'language': None, 'base...
# 59  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 0   https://www.oreilly.com/radar/four-short-links...              0
# 1   https://www.oreilly.com/radar/four-short-links...              0
# 2   https://www.oreilly.com/radar/governance-and-d...              0
# 3   https://www.oreilly.com/radar/four-short-links...              0
# 4   https://www.oreilly.com/radar/four-short-links...              0
# 5   https://www.oreilly.com/radar/four-short-links...              0
# 6   https://www.oreilly.com/radar/four-short-links...              0
# 7   https://www.oreilly.com/radar/four-short-links...              0
# 8   https://www.oreilly.com/radar/what-you-need-to...              0
# 9   https://www.oreilly.com/radar/the-unreasonable...              0
# 10  https://www.oreilly.com/radar/four-short-links...              0
# 11  https://www.oreilly.com/radar/3-ways-to-confro...              0
# 12  https://www.oreilly.com/radar/an-enterprise-vi...              0
# 13  https://www.oreilly.com/radar/leaders-need-to-...              0
# 14  https://www.oreilly.com/radar/great-leaders-in...              0
# 15  https://www.oreilly.com/radar/strong-leaders-f...              0
# 16  https://www.oreilly.com/radar/four-short-links...              0
# 17  https://www.oreilly.com/radar/four-short-links...              0
# 18  https://www.oreilly.com/radar/6-trends-framing...              0
# 19  https://www.oreilly.com/radar/four-short-links...              0
# 20  https://www.oreilly.com/radar/its-an-unprecede...              0
# 21  https://www.oreilly.com/radar/ai-adoption-in-t...              0
# 22  https://www.oreilly.com/radar/four-short-links...              0
# 23  https://www.oreilly.com/radar/four-short-links...              0
# 24  https://www.oreilly.com/radar/four-short-links...              0
# 25  https://www.oreilly.com/radar/four-short-links...              0
# 26  https://www.oreilly.com/radar/four-short-links...              0
# 27  https://www.oreilly.com/radar/four-short-links...              0
# 28  https://www.oreilly.com/radar/four-short-links...              0

# 44  https://www.oreilly.com/radar/four-short-links...
# 45    https://www.oreilly.com/radar/sometimes-i-draw/
# 46  https://www.oreilly.com/radar/from-the-trenche...
# 47  https://www.oreilly.com/radar/the-elephant-in-...
# 48  https://www.oreilly.com/radar/four-short-links...
# 49  https://www.oreilly.com/radar/four-short-links...
# 50  https://www.oreilly.com/radar/four-short-links...
# 51  https://www.oreilly.com/radar/four-short-links...
# 52  https://www.oreilly.com/radar/10-ways-to-get-u...
# 53  https://www.oreilly.com/radar/four-short-links...
# 54  https://www.oreilly.com/radar/oreilly-2020-pla...
# 55  https://www.oreilly.com/radar/four-short-links...
# 56  https://www.oreilly.com/radar/four-short-links...
# 57  https://www.oreilly.com/radar/four-short-links...
# 58  https://www.oreilly.com/radar/four-short-links...
# 59  https://www.oreilly.com/radar/the-state-of-dat...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df = df.groupby('author', as_index=False).agg({'title':'count'})
df
# Out:
#                                author  title
# 0                       Cynthia Owens      1
# 1                    George Fairbanks      1
# 2                 Hugo Bowne-Anderson      1
# 3                           Jenn Webb      4
# 4                          Kai Holnes      1
# 5                          Mac Slocum      1
# 6                       Mark Richards      1
# 7                       Martin Fowler      1
# 8                    Mary Poppendieck      1
# 9                       Mike Loukides      3
# 10                     Nat Torkington     36
# 11                      Pamela Rucker      1
# 12  Peter Skomoroch and Mike Loukides      1
# 13       Rachel Laycock and Neal Ford      1
# 14                       Rita J. King      1
# 15    Roger Magoulas and Steve Swoyer      4
# 16                       Tim O’Reilly      1

# %%
df.columns = ['author', 'count']
df.sort_values('count', ascending=False)
# Out:
#                                author  count
# 10                     Nat Torkington     36
# 15    Roger Magoulas and Steve Swoyer      4
# 3                           Jenn Webb      4
# 9                       Mike Loukides      3
# 0                       Cynthia Owens      1
# 14                       Rita J. King      1
# 13       Rachel Laycock and Neal Ford      1
# 12  Peter Skomoroch and Mike Loukides      1
# 11                      Pamela Rucker      1
# 8                    Mary Poppendieck      1
# 1                    George Fairbanks      1
# 7                       Martin Fowler      1
# 6                       Mark Richards      1
# 5                          Mac Slocum      1
# 4                          Kai Holnes      1
# 2                 Hugo Bowne-Anderson      1
# 16                       Tim O’Reilly      1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['len-Char'] = df['author'].apply(len)
# Out:
#                                author  count  len-Char
# 0                       Cynthia Owens      1        13
# 1                    George Fairbanks      1        16
# 2                 Hugo Bowne-Anderson      1        19
# 3                           Jenn Webb      4         9
# 4                          Kai Holnes      1        10
# 5                          Mac Slocum      1        10
# 6                       Mark Richards      1        13
# 7                       Martin Fowler      1        13
# 8                    Mary Poppendieck      1        16
# 9                       Mike Loukides      3        13
# 10                     Nat Torkington     36        14
# 11                      Pamela Rucker      1        13
# 12  Peter Skomoroch and Mike Loukides      1        33
# 13       Rachel Laycock and Neal Ford      1        28
# 14                       Rita J. King      1        12
# 15    Roger Magoulas and Steve Swoyer      4        31
# 16                       Tim O’Reilly      1        12

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
[e.title for e in reddit.entries if 'machine' in e.summary]
# Out:
# ['What you need to know about product management for AI',
#  'Four short links: 6 March 2020',
#  'Radar trends to watch: March 2020',
#  'Four short links: 13 February 2020']
