# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data2 = data[['RetailSales','RetailTransfers','WarehouseSales']].groupby(data['ItemType']).sum()
plt.figure(figsize=(20, 20))
data2.plot(kind='bar', figsize=(20,15))
plt.show()

# %%
len(data2.index)
# Out:
# 8

# %%
import numpy as np
x = np.arange(len(data2.index))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/3, data2['RetailSales'], width, label='RetailSales')
rects2 = ax.bar(x + 0, data2['RetailTransfers'], width, label='RetailTransfers')
rects3 = ax.bar(x + width/3, data2['WarehouseSales'], width, label='WarehouseSales')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Totals')
ax.set_title('Products')
ax.set_xticks(x)
ax.set_xticklabels(data2.index)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.tight_layout()

plt.show()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data3 = (data.RetailSales+ data.RetailTransfers+ data.WarehouseSales).groupby(data['Supplier']).sum().sort_values(ascending = False)
data3[:10].plot.bar()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data4 = data[['RetailSales','RetailTransfers','WarehouseSales']].groupby(data['Month']).mean()
plt.figure(figsize=(15, 8))  
plt.plot('RetailSales', data=data4, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot('RetailTransfers', data=data4, marker='', color='olive', linewidth=2)
plt.plot('WarehouseSales', data=data4, marker='', color='olive', linewidth=2, linestyle='dashed', label="WarehouseSales")
plt.legend()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data4.plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
#Best Method
multy=data.pivot_table(index=['Year', 'Month'], columns=['ItemType'], values=['RetailSales'], fill_value=0) 
multy.plot(figsize=(20,15))
plt.show()

# %%
#Ugli method
data5 = data[['Year','Month','ItemType','RetailSales']].groupby(['Year','Month','ItemType']).sum().sort_values(['Year','Month'])
data5.head(20)
# Out:
#                          RetailSales
# Year Month ItemType
# 2017 4     BEER                 0.00
#            LIQUOR               0.00
#            NON-ALCOHOL          0.00
#            REF                  0.00
#            STR_SUPPLIES         0.00
#            WINE                 0.00
#      5     BEER             25023.24
#            LIQUOR           35123.36
#            WINE             34546.89
#      6     BEER             27863.26
#            DUNNAGE              0.00
#            KEGS                 0.00
#            LIQUOR           35035.31
#            NON-ALCOHOL       1209.23
#            REF                 30.60
#            STR_SUPPLIES        89.22
#            WINE             33129.64
#      8     BEER             23030.13
#            DUNNAGE              0.00
#            KEGS                 0.00

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
#complete bars with the ugly method
data5.plot(kind = 'bar',figsize=(20,15))
plt.show()

# %%
#Uncompleted bars with best method
multy.plot(kind = 'bar',figsize=(20,15))
plt.show()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.lmplot(x='RetailSales', y='RetailTransfers',hue='ItemType', data=data,height=6)
plt.show()

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(data,hue='ItemType');

# %%
pd.plotting.scatter_matrix(data, figsize=(15, 15));
