# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable

titanic.select_dtypes([int,float]).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#your code here- categorical variable

titanic.select_dtypes(object).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here

plt.style.use('classic')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here

plt.figure(figsize=(12,6))
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

plt.figure(figsize=(12,18))



plt.subplot(3,1,1)
plt.hist(titanic['Age'], bins=10)

plt.subplot(3,1,2)
plt.hist(titanic['Age'], bins=20)

plt.subplot(3,1,3)
plt.hist(titanic['Age'], bins=50)

plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

'''
It does affect the plot because its changes the number of classes
that we use as well as the number of members of each.
'''
# Out:
# '\nIt does affect the plot because its changes the number of classes\nthat we use as well as the number of members of each.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here

sns.distplot(titanic['Age']);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way

titanic['Gender'].value_counts().plot(kind='bar')
plt.show()

# %%
titanic['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# your code here- 2nd way

#titanic['Gender']
sns.barplot(x=titanic['Gender'].unique(), y=titanic.groupby('Gender').count()['PassengerId']);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

plt.bar(titanic['Pclass'], titanic['Pclass'].count())
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
titanic['Age'].describe()[1:].plot(kind='bar')
plt.ylim(0,100)
plt.show()

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

''' 
The population of the boat tends to be old ith an average around
30.
'''
# Out:
# ' \nThe population of the boat tends to be old ith an average around\n30.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

sns.distplot(titanic['Age'], kde=False, color='b')
plt.show()

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

'''
It also provides us with the range of the distribution.
'''
# Out:
# '\nIt also provides us with the range of the distribution.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

sns.lmplot('Age', 'Fare', titanic)
plt.show()

# %%
# your code-2nd way

sns.jointplot('Age', 'Fare', titanic, kind='kde')
plt.show()

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr())
plt.show()

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# The most correlated features are the pairs:
#
# * Fare-Survived
# * SibSp-Parch

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

plt.figure(figsize=(20,12))
sns.violinplot(x='Pclass', y='Age', data=titanic)
plt.show()

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here


g = sns.FacetGrid(titanic, col="Gender")
g = g.map(plt.hist, 'Age')

plt.show()
