# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
# %matplotlib inline
import seaborn as sns

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn import cluster, datasets

# %%
X=StandardScaler().fit_transform(X)

# %%
#Kmeans
kmeans=cluster.KMeans(n_clusters=8)
kmeans.fit(X)

y_pred=kmeans.predict(X)

# %%
centers=kmeans.cluster_centers_

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=0.75);

# %%
from sklearn.metrics import silhouette_score

# %%
print ('Model with 8 clusters - KMeans       : Silhouette Score:{}'.format(silhouette_score(X, y_pred)))
# Out:
# Model with 8 clusters - KMeans       : Silhouette Score:0.18940140539152825

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=5)
kmeans.fit(X)

y_pred=kmeans.predict(X)

# %%
centers=kmeans.cluster_centers_

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=0.75);

# %%
print ('Model with 5 clusters - KMeans       : Silhouette Score:{}'.format(silhouette_score(X, y_pred)))
# Out:
# Model with 5 clusters - KMeans       : Silhouette Score:0.23452753694634199

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=3)
kmeans.fit(X)

y_pred=kmeans.predict(X)

# %%
centers=kmeans.cluster_centers_

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=0.75);

# %%
print ('Model with 3 clusters - KMeans       : Silhouette Score:{}'.format(silhouette_score(X, y_pred)))
# Out:
# Model with 3 clusters - KMeans       : Silhouette Score:0.2848589191898987

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
modelo=cluster.KMeans()

visual=KElbowVisualizer(modelo, k=(1, 15))
visual.fit(X)

visual.poof();
#The best cluster is number 3

# %%
n_clusters, inercia = zip(*[(k, cluster.KMeans(n_clusters=k).fit(X).inertia_) for k in range(1, 10)])

# %%
fig=plt.figure()

ax=fig.add_subplot()
ax.plot(n_clusters, inercia);

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
modelo=cluster.AgglomerativeClustering(linkage='single')

visual=KElbowVisualizer(modelo, k=(1, 15))
visual.fit(X)

visual.poof();
#The best one should be 8 using this model

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
import pandas as pd

import warnings
warnings.simplefilter('ignore')

from umap import UMAP

# %%
def get_umap(data, n):
    
    umap=UMAP(n_components=n)
    emb=umap.fit_transform(data)
    
    return pd.DataFrame(emb, columns=[f'emb_{i+1}' for i in range(n)])

# %%
umap_df=get_umap(data.data, 2)

umap_df.head()
# Out:
#        emb_1      emb_2
# 0  12.790236  -1.106385
# 1  13.179398  -0.658053
# 2  12.019213  -2.053049
# 3   9.200005  -3.941030
# 4   9.978340  10.456017

# %%
plt.scatter(umap_df.emb_1, umap_df.emb_2, c=data.target, cmap='Spectral', s=5)

plt.gca().set_aspect('equal', 'datalim')

plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))

plt.title('UMAP Projection');

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA().fit(X)

pca_x=pca.transform(X)

# %%
fig=plt.figure(figsize=(12, 8))

ax=[plt.subplot2grid((6, 1), (0, 0), rowspan=4),
    plt.subplot2grid((6, 1), (5, 0))]

ax[0].scatter(pca_x[:,0], pca_x[:,1], c=y_pred)
#plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=0.75);
ax[0].set_xlabel('PCA 1')
ax[0].set_ylabel('PCA 2')

ax[1].set_title('PCA', pad=-5)
ax[1].hlines(1, -7, 10)

y=np.ones(X.shape[0])

ax[1].plot(pca_x[:,2], y, '|', ms='20')
ax[1].axis('off')

plt.show();

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

# %%
#X,y = datasets.load_wine(return_X_y=True)

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 7))

for i,p in enumerate([5, 30, 50, 100]):
    
    tsne=TSNE(perplexity=p)
    
    x_emb=tsne.fit_transform(X)
    
    ax[i].scatter(x_emb[:,0], x_emb[:,1], c=y)
    ax[i].set_title('Perplexity={}'.format(p))
    
plt.show();
