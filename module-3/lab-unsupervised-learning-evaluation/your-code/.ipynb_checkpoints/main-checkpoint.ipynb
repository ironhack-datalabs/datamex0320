# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
kmeans=KMeans(n_clusters=8)
kmeans.fit(X)
y_pred=kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5369954815914458

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans=KMeans(n_clusters=5)
kmeans.fit(X)
y_pred=kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(X)
y_pred=kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
modelo=KMeans()

visual=KElbowVisualizer(modelo, k=(1, 10),metric='distortion')
visual.fit(X)

visual.poof();
# Out:
# /home/david/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
modelo=KMeans()

visual=KElbowVisualizer(modelo, k=(2, 10),metric='silhouette')
visual.fit(X)

visual.poof();
# Out:
# /home/david/.local/lib/python3.6/site-packages/yellowbrick/utils/kneed.py:182: YellowbrickWarning: No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /home/david/.local/lib/python3.6/site-packages/yellowbrick/utils/kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /home/david/.local/lib/python3.6/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
modelo=KMeans()
visual=KElbowVisualizer(modelo, k=(2, 10), metric='calinski_harabasz')
visual.fit(X)

visual.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
from sklearn.cluster import AgglomerativeClustering
modelo=AgglomerativeClustering()

visual=KElbowVisualizer(modelo, k=(1, 10),metric='distortion')
visual.fit(X)

visual.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
import seaborn as sns
bin1 = ['alcohol', 'malic_acid', 'ash', 'labels']
bin2 = ['alcalinity_of_ash','magnesium', 'total_phenols', 'labels']
bin3 = ['flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'labels']
bin4 = ['color_intensity','hue','od280/od315_of_diluted_wines','proline','labels']
X['labels'] = kmeans.fit(X).labels_
X1=X[bin1]
sns.set(style='ticks')
sns.pairplot(X1,hue='labels');

# %%
X1=X[bin2]
sns.set(style='ticks')
sns.pairplot(X1,hue='labels');

# %%
X1=X[bin3]
sns.set(style='ticks')
sns.pairplot(X1,hue='labels');

# %%
X1=X[bin4]
sns.set(style='ticks')
sns.pairplot(X1,hue='labels');

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca=PCA().fit(X)

pca_x=pca.transform(X)

fig=plt.figure(figsize=(12, 8))

ax=[plt.subplot2grid((6, 1), (0, 0), rowspan=4)]

ax[0].scatter(pca_x[:,0], pca_x[:,1],c=X.labels)

plt.show();

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE
fig, ax = plt.subplots(1, 4, figsize=(15, 7))

for i,p in enumerate([1, 5, 20, 50]):
    
    tsne=TSNE(perplexity=p)
    
    x_emb=tsne.fit_transform(X)
    
    ax[i].scatter(x_emb[:,0], x_emb[:,1], c=X.labels)
    ax[i].set_title('Perplexity={}'.format(p))
    
plt.show();
