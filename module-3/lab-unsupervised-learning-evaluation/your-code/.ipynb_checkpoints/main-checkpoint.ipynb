# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %%
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
y.unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import cluster, datasets
from sklearn.metrics import silhouette_score

# %%
X=StandardScaler().fit_transform(X)

# %%
kmeans=cluster.KMeans(n_clusters=8)
kmeans.fit(X)

y_pred=kmeans.predict(X)

# %%
print ('Modelo 1 : Silhouette Score:{}'.format(silhouette_score(X, y_pred)))
# Out:
# Modelo 1 : Silhouette Score:0.1519553624627793

# %%
#veamos un scatterplot

plt.figure(figsize=(12,6))
plt.scatter(X[:,0], X[:,1], c=y_pred)

# %%
#pintando centros
centers=kmeans.cluster_centers_
plt.figure(figsize=(12,6))
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.scatter(centers[:,0], centers[:,1], c='red')

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=5)
kmeans.fit(X)

y_pred=kmeans.predict(X)

# %%
print ('Modelo 2 : Silhouette Score:{}'.format(silhouette_score(X, y_pred)))
# Out:
# Modelo 2 : Silhouette Score:0.2285110933052902

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=3)
kmeans.fit(X)

y_pred=kmeans.predict(X)

# %%
print ('Modelo 3 : Silhouette Score:{}'.format(silhouette_score(X, y_pred)))
# Out:
# Modelo 3 : Silhouette Score:0.2848589191898987

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
inercias=[]

for i in range(1, 10):
    kmeans=cluster.KMeans(n_clusters=i).fit(X)
    inercias.append(kmeans.inertia_)

# %%
plt.plot(range(1, 10), inercias);

# %%
from yellowbrick.cluster import KElbowVisualizer
# Out:
# /home/sromero/.local/lib/python3.6/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
modelo=cluster.KMeans()

visual=KElbowVisualizer(modelo, k=(1, 15))
visual.fit(X)

visual.poof();

# %%
modelo=cluster.KMeans()

visual=KElbowVisualizer(modelo, k=(1, 15), metric='distortion')
visual.fit(X)

visual.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
modelo=cluster.AgglomerativeClustering(linkage='single')

visual=KElbowVisualizer(modelo, k=(1, 15))
visual.fit(X)

visual.poof();

# %%
modelo=cluster.AgglomerativeClustering(linkage='single')

visual=KElbowVisualizer(modelo, k=(1, 15), metric='distortion')
visual.fit(X)

visual.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
kmeans=cluster.KMeans(n_clusters=8)
kmeans.fit(X)
y_pred=kmeans.predict(X)

# %%
plt.figure(figsize=(12,6))
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=0.75);

# %%
#con UMAP
from umap import UMAP

# %%
def get_umap(data, n):
    
    umap=UMAP(n_components=n)
    emb=umap.fit_transform(data)
    
    return pd.DataFrame(emb, columns=[f'emb_{i+1}' for i in range(n)])

# %%
umap_df=get_umap(data.data, 2)

umap_df.head()
# Out:
#        emb_1     emb_2
# 0  15.736645  2.943879
# 1  15.835592  3.493634
# 2  15.645971  1.796312
# 3  14.616045 -1.439834
# 4   9.837791  9.165690

# %%
plt.scatter(umap_df.emb_1, umap_df.emb_2, c=data.target, cmap='Spectral', s=5)

plt.gca().set_aspect('equal', 'datalim')

plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))

plt.title('UMAP Projection');

# %%
#UMAP supervisado
emb=UMAP().fit_transform(data.data, y=data.target)  # y=target es para supervisado

umap_df=pd.DataFrame(emb, columns=['emb_1', 'emb_2'])


plt.scatter(umap_df.emb_1, umap_df.emb_2, c=data.target, cmap='Spectral', s=5)

plt.gca().set_aspect('equal', 'datalim')

plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))

plt.title('UMAP Projection');

# %%
umap_df=get_umap(X, 2)

plt.scatter(umap_df.emb_1, umap_df.emb_2);

# %%
X,y=datasets.make_blobs(n_features=8, centers=8)

plt.scatter(X[:,0], X[:,1]);

# %%
umap_df=get_umap(X, 2)

plt.scatter(umap_df.emb_1, umap_df.emb_2);

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')

ax.scatter(umap_df.emb_1, umap_df.emb_2);

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA().fit(X)

pca_x=pca.transform(X)

# %%
fig=plt.figure(figsize=(12, 8))

ax=[plt.subplot2grid((6, 1), (0, 0), rowspan=4),
    plt.subplot2grid((6, 1), (5, 0))]

ax[0].scatter(pca_x[:,0], pca_x[:,1], c=y_pred)
#plt.scatter(centers[:,0], centers[:,1], c='red', s=50, alpha=0.75);
ax[0].set_xlabel('PCA 1')
ax[0].set_ylabel('PCA 2')

ax[1].set_title('PCA', pad=-5)
ax[1].hlines(1, -7, 10)

y=np.ones(X.shape[0])

ax[1].plot(pca_x[:,2], y, '|', ms='20')
ax[1].axis('off')

plt.show();

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 7))

for i,p in enumerate([5, 30, 50, 100]):
    
    tsne=TSNE(perplexity=p)
    
    x_emb=tsne.fit_transform(X)
    
    ax[i].scatter(x_emb[:,0], x_emb[:,1], c=y)
    ax[i].set_title('Perplexity={}'.format(p))
    
plt.show();
